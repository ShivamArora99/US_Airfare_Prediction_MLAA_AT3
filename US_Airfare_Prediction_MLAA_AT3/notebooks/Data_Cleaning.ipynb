# %%
import os
import zipfile

import pandas as pd

# %%
import os
import zipfile

def unzip_and_split_subfolders(parent_folder):
  """
  Unzips all .zip files found within subfolders of a parent folder.
  Creates separate folders for each zip file's contents, named 
  after the zip file, within the respective subfolders.
  Includes checks to ensure unzipping was successful.

  Args:
    parent_folder: The path to the parent folder containing the subfolders.
  """

  print("Unzipping all .zip files...")

  # Check if the parent folder exists
  if not os.path.exists(parent_folder):
    print(f"ERROR: Parent folder not found: {parent_folder}")
    return  # Exit the function if the parent folder doesn't exist

  for root, dirs, files in os.walk(parent_folder):
    print(f"Checking in: {root}")  # Print the current directory being checked

    for file in files:
      if file.endswith(".zip"):
        zip_file_path = os.path.join(root, file)
        print("Zip file path:", zip_file_path)
        folder_name = file[:-4]  # Remove .zip extension
        folder_path = os.path.join(root, folder_name) 

        try:
          with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(folder_path)

          # Check if the folder was created and is not empty
          if os.path.isdir(folder_path) and os.listdir(folder_path):
            print(f"Successfully unzipped {file} to {folder_path}")
          else:
            print(f"WARNING: Failed to unzip or folder is empty: {zip_file_path}")
        except zipfile.BadZipFile:
          print(f"ERROR: {zip_file_path} is a corrupted zip file.")
        except Exception as e:
          print(f"ERROR: An unexpected error occurred while unzipping {zip_file_path}: {e}")

if __name__ == "__main__":
  parent_folder = "../data/raw/itineraries_csv"  # Replace with the actual path
  unzip_and_split_subfolders(parent_folder)
# Out:
# Unzipping all .zip files...
# Checking in: ../data/raw/itineraries_csv
# Checking in: ../data/raw/itineraries_csv\ATL
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_aa.zip
# Successfully unzipped ATL_itineraries_aa.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_aa
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ab.zip
# Successfully unzipped ATL_itineraries_ab.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ab
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ac.zip
# Successfully unzipped ATL_itineraries_ac.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ac
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ad.zip
# Successfully unzipped ATL_itineraries_ad.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ad
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ae.zip
# Successfully unzipped ATL_itineraries_ae.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ae
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_af.zip
# Successfully unzipped ATL_itineraries_af.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_af
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ag.zip
# Successfully unzipped ATL_itineraries_ag.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ag
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ah.zip
# Successfully unzipped ATL_itineraries_ah.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ah
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ai.zip
# Successfully unzipped ATL_itineraries_ai.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ai
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_aj.zip
# Successfully unzipped ATL_itineraries_aj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_aj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ak.zip
# Successfully unzipped ATL_itineraries_ak.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ak
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_al.zip
# Successfully unzipped ATL_itineraries_al.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_al
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_am.zip
# Successfully unzipped ATL_itineraries_am.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_am
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_an.zip
# Successfully unzipped ATL_itineraries_an.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_an
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ao.zip
# Successfully unzipped ATL_itineraries_ao.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ao
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ap.zip
# Successfully unzipped ATL_itineraries_ap.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ap
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_aq.zip
# Successfully unzipped ATL_itineraries_aq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_aq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ar.zip
# Successfully unzipped ATL_itineraries_ar.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ar
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_as.zip
# Successfully unzipped ATL_itineraries_as.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_as
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_at.zip
# Successfully unzipped ATL_itineraries_at.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_at
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_au.zip
# Successfully unzipped ATL_itineraries_au.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_au
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_av.zip
# Successfully unzipped ATL_itineraries_av.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_av
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_aw.zip
# Successfully unzipped ATL_itineraries_aw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_aw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ax.zip
# Successfully unzipped ATL_itineraries_ax.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ax
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ay.zip
# Successfully unzipped ATL_itineraries_ay.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ay
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_az.zip
# Successfully unzipped ATL_itineraries_az.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_az
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ba.zip
# Successfully unzipped ATL_itineraries_ba.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ba
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bb.zip
# Successfully unzipped ATL_itineraries_bb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bc.zip
# Successfully unzipped ATL_itineraries_bc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bd.zip
# Successfully unzipped ATL_itineraries_bd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_be.zip
# Successfully unzipped ATL_itineraries_be.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_be
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bf.zip
# Successfully unzipped ATL_itineraries_bf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bg.zip
# Successfully unzipped ATL_itineraries_bg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bh.zip
# Successfully unzipped ATL_itineraries_bh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bi.zip
# Successfully unzipped ATL_itineraries_bi.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bi
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bj.zip
# Successfully unzipped ATL_itineraries_bj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bk.zip
# Successfully unzipped ATL_itineraries_bk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bl.zip
# Successfully unzipped ATL_itineraries_bl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bm.zip
# Successfully unzipped ATL_itineraries_bm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bn.zip
# Successfully unzipped ATL_itineraries_bn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bo.zip
# Successfully unzipped ATL_itineraries_bo.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bo
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bp.zip
# Successfully unzipped ATL_itineraries_bp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bq.zip
# Successfully unzipped ATL_itineraries_bq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_br.zip
# Successfully unzipped ATL_itineraries_br.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_br
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bs.zip
# Successfully unzipped ATL_itineraries_bs.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bs
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bt.zip
# Successfully unzipped ATL_itineraries_bt.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bt
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bu.zip
# Successfully unzipped ATL_itineraries_bu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bv.zip
# Successfully unzipped ATL_itineraries_bv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bw.zip
# Successfully unzipped ATL_itineraries_bw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bx.zip
# Successfully unzipped ATL_itineraries_bx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_by.zip
# Successfully unzipped ATL_itineraries_by.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_by
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_bz.zip
# Successfully unzipped ATL_itineraries_bz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_bz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ca.zip
# Successfully unzipped ATL_itineraries_ca.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ca
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cb.zip
# Successfully unzipped ATL_itineraries_cb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cc.zip
# Successfully unzipped ATL_itineraries_cc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cd.zip
# Successfully unzipped ATL_itineraries_cd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ce.zip
# Successfully unzipped ATL_itineraries_ce.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ce
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cf.zip
# Successfully unzipped ATL_itineraries_cf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cg.zip
# Successfully unzipped ATL_itineraries_cg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ch.zip
# Successfully unzipped ATL_itineraries_ch.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ch
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ci.zip
# Successfully unzipped ATL_itineraries_ci.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ci
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cj.zip
# Successfully unzipped ATL_itineraries_cj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ck.zip
# Successfully unzipped ATL_itineraries_ck.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ck
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cl.zip
# Successfully unzipped ATL_itineraries_cl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cm.zip
# Successfully unzipped ATL_itineraries_cm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cn.zip
# Successfully unzipped ATL_itineraries_cn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_co.zip
# Successfully unzipped ATL_itineraries_co.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_co
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cp.zip
# Successfully unzipped ATL_itineraries_cp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cq.zip
# Successfully unzipped ATL_itineraries_cq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cr.zip
# Successfully unzipped ATL_itineraries_cr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cs.zip
# Successfully unzipped ATL_itineraries_cs.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cs
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ct.zip
# Successfully unzipped ATL_itineraries_ct.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ct
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cu.zip
# Successfully unzipped ATL_itineraries_cu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cv.zip
# Successfully unzipped ATL_itineraries_cv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cw.zip
# Successfully unzipped ATL_itineraries_cw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cx.zip
# Successfully unzipped ATL_itineraries_cx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cy.zip
# Successfully unzipped ATL_itineraries_cy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_cz.zip
# Successfully unzipped ATL_itineraries_cz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_cz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_da.zip
# Successfully unzipped ATL_itineraries_da.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_da
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_db.zip
# Successfully unzipped ATL_itineraries_db.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_db
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dc.zip
# Successfully unzipped ATL_itineraries_dc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dd.zip
# Successfully unzipped ATL_itineraries_dd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_de.zip
# Successfully unzipped ATL_itineraries_de.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_de
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_df.zip
# Successfully unzipped ATL_itineraries_df.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_df
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dg.zip
# Successfully unzipped ATL_itineraries_dg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dh.zip
# Successfully unzipped ATL_itineraries_dh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_di.zip
# Successfully unzipped ATL_itineraries_di.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_di
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dj.zip
# Successfully unzipped ATL_itineraries_dj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dk.zip
# Successfully unzipped ATL_itineraries_dk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dl.zip
# Successfully unzipped ATL_itineraries_dl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dm.zip
# Successfully unzipped ATL_itineraries_dm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dn.zip
# Successfully unzipped ATL_itineraries_dn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_do.zip
# Successfully unzipped ATL_itineraries_do.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_do
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dp.zip
# Successfully unzipped ATL_itineraries_dp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dq.zip
# Successfully unzipped ATL_itineraries_dq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dr.zip
# Successfully unzipped ATL_itineraries_dr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ds.zip
# Successfully unzipped ATL_itineraries_ds.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ds
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dt.zip
# Successfully unzipped ATL_itineraries_dt.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dt
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_du.zip
# Successfully unzipped ATL_itineraries_du.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_du
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dv.zip
# Successfully unzipped ATL_itineraries_dv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dw.zip
# Successfully unzipped ATL_itineraries_dw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dx.zip
# Successfully unzipped ATL_itineraries_dx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dy.zip
# Successfully unzipped ATL_itineraries_dy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_dz.zip
# Successfully unzipped ATL_itineraries_dz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_dz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ea.zip
# Successfully unzipped ATL_itineraries_ea.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ea
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eb.zip
# Successfully unzipped ATL_itineraries_eb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ec.zip
# Successfully unzipped ATL_itineraries_ec.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ec
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ed.zip
# Successfully unzipped ATL_itineraries_ed.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ed
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ee.zip
# Successfully unzipped ATL_itineraries_ee.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ee
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ef.zip
# Successfully unzipped ATL_itineraries_ef.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ef
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eg.zip
# Successfully unzipped ATL_itineraries_eg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eh.zip
# Successfully unzipped ATL_itineraries_eh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ei.zip
# Successfully unzipped ATL_itineraries_ei.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ei
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ej.zip
# Successfully unzipped ATL_itineraries_ej.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ej
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ek.zip
# Successfully unzipped ATL_itineraries_ek.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ek
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_el.zip
# Successfully unzipped ATL_itineraries_el.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_el
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_em.zip
# Successfully unzipped ATL_itineraries_em.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_em
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_en.zip
# Successfully unzipped ATL_itineraries_en.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_en
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eo.zip
# Successfully unzipped ATL_itineraries_eo.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eo
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ep.zip
# Successfully unzipped ATL_itineraries_ep.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ep
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eq.zip
# Successfully unzipped ATL_itineraries_eq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_er.zip
# Successfully unzipped ATL_itineraries_er.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_er
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_es.zip
# Successfully unzipped ATL_itineraries_es.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_es
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_et.zip
# Successfully unzipped ATL_itineraries_et.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_et
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_eu.zip
# Successfully unzipped ATL_itineraries_eu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_eu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ev.zip
# Successfully unzipped ATL_itineraries_ev.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ev
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ew.zip
# Successfully unzipped ATL_itineraries_ew.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ew
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ex.zip
# Successfully unzipped ATL_itineraries_ex.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ex
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ey.zip
# Successfully unzipped ATL_itineraries_ey.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ey
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ez.zip
# Successfully unzipped ATL_itineraries_ez.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ez
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fa.zip
# Successfully unzipped ATL_itineraries_fa.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fa
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fb.zip
# Successfully unzipped ATL_itineraries_fb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fc.zip
# Successfully unzipped ATL_itineraries_fc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fd.zip
# Successfully unzipped ATL_itineraries_fd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fe.zip
# Successfully unzipped ATL_itineraries_fe.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fe
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ff.zip
# Successfully unzipped ATL_itineraries_ff.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ff
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fg.zip
# Successfully unzipped ATL_itineraries_fg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fh.zip
# Successfully unzipped ATL_itineraries_fh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fi.zip
# Successfully unzipped ATL_itineraries_fi.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fi
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fj.zip
# Successfully unzipped ATL_itineraries_fj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fk.zip
# Successfully unzipped ATL_itineraries_fk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fl.zip
# Successfully unzipped ATL_itineraries_fl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fm.zip
# Successfully unzipped ATL_itineraries_fm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fn.zip
# Successfully unzipped ATL_itineraries_fn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fo.zip
# Successfully unzipped ATL_itineraries_fo.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fo
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fp.zip
# Successfully unzipped ATL_itineraries_fp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fq.zip
# Successfully unzipped ATL_itineraries_fq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fr.zip
# Successfully unzipped ATL_itineraries_fr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fs.zip
# Successfully unzipped ATL_itineraries_fs.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fs
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ft.zip
# Successfully unzipped ATL_itineraries_ft.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ft
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fu.zip
# Successfully unzipped ATL_itineraries_fu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fv.zip
# Successfully unzipped ATL_itineraries_fv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fw.zip
# Successfully unzipped ATL_itineraries_fw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fx.zip
# Successfully unzipped ATL_itineraries_fx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fy.zip
# Successfully unzipped ATL_itineraries_fy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_fz.zip
# Successfully unzipped ATL_itineraries_fz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_fz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ga.zip
# Successfully unzipped ATL_itineraries_ga.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ga
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gb.zip
# Successfully unzipped ATL_itineraries_gb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gc.zip
# Successfully unzipped ATL_itineraries_gc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gd.zip
# Successfully unzipped ATL_itineraries_gd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ge.zip
# Successfully unzipped ATL_itineraries_ge.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ge
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gf.zip
# Successfully unzipped ATL_itineraries_gf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gg.zip
# Successfully unzipped ATL_itineraries_gg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gh.zip
# Successfully unzipped ATL_itineraries_gh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gi.zip
# Successfully unzipped ATL_itineraries_gi.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gi
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gj.zip
# Successfully unzipped ATL_itineraries_gj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gk.zip
# Successfully unzipped ATL_itineraries_gk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gl.zip
# Successfully unzipped ATL_itineraries_gl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gm.zip
# Successfully unzipped ATL_itineraries_gm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gn.zip
# Successfully unzipped ATL_itineraries_gn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_go.zip
# Successfully unzipped ATL_itineraries_go.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_go
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gp.zip
# Successfully unzipped ATL_itineraries_gp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gq.zip
# Successfully unzipped ATL_itineraries_gq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gr.zip
# Successfully unzipped ATL_itineraries_gr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gs.zip
# Successfully unzipped ATL_itineraries_gs.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gs
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gt.zip
# Successfully unzipped ATL_itineraries_gt.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gt
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gu.zip
# Successfully unzipped ATL_itineraries_gu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gv.zip
# Successfully unzipped ATL_itineraries_gv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gw.zip
# Successfully unzipped ATL_itineraries_gw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gx.zip
# Successfully unzipped ATL_itineraries_gx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gy.zip
# Successfully unzipped ATL_itineraries_gy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_gz.zip
# Successfully unzipped ATL_itineraries_gz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_gz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ha.zip
# Successfully unzipped ATL_itineraries_ha.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ha
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hb.zip
# Successfully unzipped ATL_itineraries_hb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hc.zip
# Successfully unzipped ATL_itineraries_hc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hd.zip
# Successfully unzipped ATL_itineraries_hd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_he.zip
# Successfully unzipped ATL_itineraries_he.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_he
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hf.zip
# Successfully unzipped ATL_itineraries_hf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hg.zip
# Successfully unzipped ATL_itineraries_hg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hh.zip
# Successfully unzipped ATL_itineraries_hh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hi.zip
# Successfully unzipped ATL_itineraries_hi.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hi
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hj.zip
# Successfully unzipped ATL_itineraries_hj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hk.zip
# Successfully unzipped ATL_itineraries_hk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hl.zip
# Successfully unzipped ATL_itineraries_hl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hm.zip
# Successfully unzipped ATL_itineraries_hm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hn.zip
# Successfully unzipped ATL_itineraries_hn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ho.zip
# Successfully unzipped ATL_itineraries_ho.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ho
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hp.zip
# Successfully unzipped ATL_itineraries_hp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hq.zip
# Successfully unzipped ATL_itineraries_hq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hr.zip
# Successfully unzipped ATL_itineraries_hr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hs.zip
# Successfully unzipped ATL_itineraries_hs.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hs
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ht.zip
# Successfully unzipped ATL_itineraries_ht.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ht
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hu.zip
# Successfully unzipped ATL_itineraries_hu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hv.zip
# Successfully unzipped ATL_itineraries_hv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hw.zip
# Successfully unzipped ATL_itineraries_hw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hx.zip
# Successfully unzipped ATL_itineraries_hx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hy.zip
# Successfully unzipped ATL_itineraries_hy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_hz.zip
# Successfully unzipped ATL_itineraries_hz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_hz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ia.zip
# Successfully unzipped ATL_itineraries_ia.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ia
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ib.zip
# Successfully unzipped ATL_itineraries_ib.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ib
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ic.zip
# Successfully unzipped ATL_itineraries_ic.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ic
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_id.zip
# Successfully unzipped ATL_itineraries_id.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_id
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ie.zip
# Successfully unzipped ATL_itineraries_ie.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ie
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_if.zip
# Successfully unzipped ATL_itineraries_if.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_if
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ig.zip
# Successfully unzipped ATL_itineraries_ig.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ig
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ih.zip
# Successfully unzipped ATL_itineraries_ih.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ih
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ii.zip
# Successfully unzipped ATL_itineraries_ii.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ii
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ij.zip
# Successfully unzipped ATL_itineraries_ij.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ij
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ik.zip
# Successfully unzipped ATL_itineraries_ik.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ik
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_il.zip
# Successfully unzipped ATL_itineraries_il.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_il
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_im.zip
# Successfully unzipped ATL_itineraries_im.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_im
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_in.zip
# Successfully unzipped ATL_itineraries_in.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_in
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_io.zip
# Successfully unzipped ATL_itineraries_io.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_io
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ip.zip
# Successfully unzipped ATL_itineraries_ip.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ip
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iq.zip
# Successfully unzipped ATL_itineraries_iq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ir.zip
# Successfully unzipped ATL_itineraries_ir.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ir
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_is.zip
# Successfully unzipped ATL_itineraries_is.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_is
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_it.zip
# Successfully unzipped ATL_itineraries_it.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_it
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iu.zip
# Successfully unzipped ATL_itineraries_iu.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iu
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iv.zip
# Successfully unzipped ATL_itineraries_iv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iw.zip
# Successfully unzipped ATL_itineraries_iw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ix.zip
# Successfully unzipped ATL_itineraries_ix.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ix
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iy.zip
# Successfully unzipped ATL_itineraries_iy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_iz.zip
# Successfully unzipped ATL_itineraries_iz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_iz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ja.zip
# Successfully unzipped ATL_itineraries_ja.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ja
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jb.zip
# Successfully unzipped ATL_itineraries_jb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jc.zip
# Successfully unzipped ATL_itineraries_jc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jd.zip
# Successfully unzipped ATL_itineraries_jd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_je.zip
# Successfully unzipped ATL_itineraries_je.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_je
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jf.zip
# Successfully unzipped ATL_itineraries_jf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jg.zip
# Successfully unzipped ATL_itineraries_jg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jh.zip
# Successfully unzipped ATL_itineraries_jh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ji.zip
# Successfully unzipped ATL_itineraries_ji.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ji
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jj.zip
# Successfully unzipped ATL_itineraries_jj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jk.zip
# Successfully unzipped ATL_itineraries_jk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jl.zip
# Successfully unzipped ATL_itineraries_jl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jm.zip
# Successfully unzipped ATL_itineraries_jm.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jm
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jn.zip
# Successfully unzipped ATL_itineraries_jn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jo.zip
# Successfully unzipped ATL_itineraries_jo.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jo
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jp.zip
# Successfully unzipped ATL_itineraries_jp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jq.zip
# Successfully unzipped ATL_itineraries_jq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jr.zip
# Successfully unzipped ATL_itineraries_jr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_js.zip
# Successfully unzipped ATL_itineraries_js.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_js
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jt.zip
# Successfully unzipped ATL_itineraries_jt.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jt
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ju.zip
# Successfully unzipped ATL_itineraries_ju.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ju
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jv.zip
# Successfully unzipped ATL_itineraries_jv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jw.zip
# Successfully unzipped ATL_itineraries_jw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jw
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jx.zip
# Successfully unzipped ATL_itineraries_jx.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jx
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jy.zip
# Successfully unzipped ATL_itineraries_jy.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jy
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_jz.zip
# Successfully unzipped ATL_itineraries_jz.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_jz
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ka.zip
# Successfully unzipped ATL_itineraries_ka.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ka
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kb.zip
# Successfully unzipped ATL_itineraries_kb.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kb
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kc.zip
# Successfully unzipped ATL_itineraries_kc.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kc
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kd.zip
# Successfully unzipped ATL_itineraries_kd.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kd
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ke.zip
# Successfully unzipped ATL_itineraries_ke.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ke
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kf.zip
# Successfully unzipped ATL_itineraries_kf.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kf
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kg.zip
# Successfully unzipped ATL_itineraries_kg.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kg
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kh.zip
# Successfully unzipped ATL_itineraries_kh.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kh
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ki.zip
# Successfully unzipped ATL_itineraries_ki.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ki
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kj.zip
# Successfully unzipped ATL_itineraries_kj.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kj
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kk.zip
# Successfully unzipped ATL_itineraries_kk.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kk
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kl.zip
# Successfully unzipped ATL_itineraries_kl.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kl
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_km.zip
# Successfully unzipped ATL_itineraries_km.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_km
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kn.zip
# Successfully unzipped ATL_itineraries_kn.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kn
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ko.zip
# Successfully unzipped ATL_itineraries_ko.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ko
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kp.zip
# Successfully unzipped ATL_itineraries_kp.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kp
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kq.zip
# Successfully unzipped ATL_itineraries_kq.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kq
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kr.zip
# Successfully unzipped ATL_itineraries_kr.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kr
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ks.zip
# Successfully unzipped ATL_itineraries_ks.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ks
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kt.zip
# Successfully unzipped ATL_itineraries_kt.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kt
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_ku.zip
# Successfully unzipped ATL_itineraries_ku.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_ku
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kv.zip
# Successfully unzipped ATL_itineraries_kv.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kv
# Zip file path: ../data/raw/itineraries_csv\ATL\ATL_itineraries_kw.zip
# Successfully unzipped ATL_itineraries_kw.zip to ../data/raw/itineraries_csv\ATL\ATL_itineraries_kw
# ...
# Successfully unzipped SFO_itineraries_wj.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wj
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wk.zip
# Successfully unzipped SFO_itineraries_wk.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wk
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wl.zip
# Successfully unzipped SFO_itineraries_wl.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wl
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wm.zip
# Successfully unzipped SFO_itineraries_wm.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wm
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wn.zip
# Successfully unzipped SFO_itineraries_wn.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wn
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wo.zip
# Successfully unzipped SFO_itineraries_wo.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wo
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wp.zip
# Successfully unzipped SFO_itineraries_wp.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wp
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wq.zip
# Successfully unzipped SFO_itineraries_wq.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wq
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wr.zip
# Successfully unzipped SFO_itineraries_wr.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wr
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ws.zip
# Successfully unzipped SFO_itineraries_ws.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ws
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wt.zip
# Successfully unzipped SFO_itineraries_wt.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wt
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wu.zip
# Successfully unzipped SFO_itineraries_wu.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wu
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wv.zip
# Successfully unzipped SFO_itineraries_wv.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wv
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ww.zip
# Successfully unzipped SFO_itineraries_ww.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ww
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wx.zip
# Successfully unzipped SFO_itineraries_wx.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wx
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wy.zip
# Successfully unzipped SFO_itineraries_wy.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wy
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_wz.zip
# Successfully unzipped SFO_itineraries_wz.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_wz
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xa.zip
# Successfully unzipped SFO_itineraries_xa.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xa
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xb.zip
# Successfully unzipped SFO_itineraries_xb.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xb
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xc.zip
# Successfully unzipped SFO_itineraries_xc.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xc
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xd.zip
# Successfully unzipped SFO_itineraries_xd.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xd
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xe.zip
# Successfully unzipped SFO_itineraries_xe.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xe
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xf.zip
# Successfully unzipped SFO_itineraries_xf.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xf
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xg.zip
# Successfully unzipped SFO_itineraries_xg.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xg
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xh.zip
# Successfully unzipped SFO_itineraries_xh.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xh
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xi.zip
# Successfully unzipped SFO_itineraries_xi.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xi
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xj.zip
# Successfully unzipped SFO_itineraries_xj.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xj
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xk.zip
# Successfully unzipped SFO_itineraries_xk.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xk
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xl.zip
# Successfully unzipped SFO_itineraries_xl.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xl
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xm.zip
# Successfully unzipped SFO_itineraries_xm.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xm
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xn.zip
# Successfully unzipped SFO_itineraries_xn.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xn
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xo.zip
# Successfully unzipped SFO_itineraries_xo.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xo
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xp.zip
# Successfully unzipped SFO_itineraries_xp.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xp
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xq.zip
# Successfully unzipped SFO_itineraries_xq.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xq
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xr.zip
# Successfully unzipped SFO_itineraries_xr.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xr
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xs.zip
# Successfully unzipped SFO_itineraries_xs.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xs
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xt.zip
# Successfully unzipped SFO_itineraries_xt.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xt
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xu.zip
# Successfully unzipped SFO_itineraries_xu.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xu
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xv.zip
# Successfully unzipped SFO_itineraries_xv.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xv
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xw.zip
# Successfully unzipped SFO_itineraries_xw.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xw
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xx.zip
# Successfully unzipped SFO_itineraries_xx.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xx
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xy.zip
# Successfully unzipped SFO_itineraries_xy.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xy
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_xz.zip
# Successfully unzipped SFO_itineraries_xz.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_xz
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ya.zip
# Successfully unzipped SFO_itineraries_ya.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ya
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yb.zip
# Successfully unzipped SFO_itineraries_yb.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yb
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yc.zip
# Successfully unzipped SFO_itineraries_yc.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yc
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yd.zip
# Successfully unzipped SFO_itineraries_yd.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yd
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ye.zip
# Successfully unzipped SFO_itineraries_ye.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ye
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yf.zip
# Successfully unzipped SFO_itineraries_yf.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yf
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yg.zip
# Successfully unzipped SFO_itineraries_yg.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yg
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yh.zip
# Successfully unzipped SFO_itineraries_yh.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yh
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yi.zip
# Successfully unzipped SFO_itineraries_yi.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yi
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yj.zip
# Successfully unzipped SFO_itineraries_yj.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yj
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yk.zip
# Successfully unzipped SFO_itineraries_yk.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yk
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yl.zip
# Successfully unzipped SFO_itineraries_yl.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yl
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ym.zip
# Successfully unzipped SFO_itineraries_ym.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ym
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yn.zip
# Successfully unzipped SFO_itineraries_yn.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yn
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yo.zip
# Successfully unzipped SFO_itineraries_yo.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yo
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yp.zip
# Successfully unzipped SFO_itineraries_yp.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yp
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yq.zip
# Successfully unzipped SFO_itineraries_yq.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yq
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yr.zip
# Successfully unzipped SFO_itineraries_yr.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yr
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ys.zip
# Successfully unzipped SFO_itineraries_ys.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ys
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yt.zip
# Successfully unzipped SFO_itineraries_yt.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yt
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yu.zip
# Successfully unzipped SFO_itineraries_yu.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yu
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yv.zip
# Successfully unzipped SFO_itineraries_yv.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yv
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yw.zip
# Successfully unzipped SFO_itineraries_yw.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yw
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yx.zip
# Successfully unzipped SFO_itineraries_yx.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yx
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yy.zip
# Successfully unzipped SFO_itineraries_yy.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yy
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_yz.zip
# Successfully unzipped SFO_itineraries_yz.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_yz
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_za.zip
# Successfully unzipped SFO_itineraries_za.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_za
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zb.zip
# Successfully unzipped SFO_itineraries_zb.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zb
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zc.zip
# Successfully unzipped SFO_itineraries_zc.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zc
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zd.zip
# Successfully unzipped SFO_itineraries_zd.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zd
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_ze.zip
# Successfully unzipped SFO_itineraries_ze.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_ze
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zf.zip
# Successfully unzipped SFO_itineraries_zf.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zf
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zg.zip
# Successfully unzipped SFO_itineraries_zg.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zg
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zh.zip
# Successfully unzipped SFO_itineraries_zh.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zh
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zi.zip
# Successfully unzipped SFO_itineraries_zi.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zi
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zj.zip
# Successfully unzipped SFO_itineraries_zj.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zj
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zk.zip
# Successfully unzipped SFO_itineraries_zk.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zk
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zl.zip
# Successfully unzipped SFO_itineraries_zl.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zl
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zm.zip
# Successfully unzipped SFO_itineraries_zm.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zm
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zn.zip
# Successfully unzipped SFO_itineraries_zn.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zn
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zo.zip
# Successfully unzipped SFO_itineraries_zo.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zo
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zp.zip
# Successfully unzipped SFO_itineraries_zp.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zp
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zq.zip
# Successfully unzipped SFO_itineraries_zq.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zq
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zr.zip
# Successfully unzipped SFO_itineraries_zr.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zr
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zs.zip
# Successfully unzipped SFO_itineraries_zs.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zs
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zt.zip
# Successfully unzipped SFO_itineraries_zt.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zt
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zu.zip
# Successfully unzipped SFO_itineraries_zu.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zu
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zv.zip
# Successfully unzipped SFO_itineraries_zv.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zv
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zw.zip
# Successfully unzipped SFO_itineraries_zw.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zw
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zx.zip
# Successfully unzipped SFO_itineraries_zx.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zx
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zy.zip
# Successfully unzipped SFO_itineraries_zy.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zy
# Zip file path: ../data/raw/itineraries_csv\SFO\SFO_itineraries_zz.zip
# Successfully unzipped SFO_itineraries_zz.zip to ../data/raw/itineraries_csv\SFO\SFO_itineraries_zz

# %%
def data_reading(parent_folder):
  """
  Reads data from zip files found within subfolders of a parent folder.
  :param parent_folder: 
  :return: multiple dataframes containing data from zip files found within subfolders.
  """
  dataframes  = {}
  for root, dirs, files in os.walk(parent_folder):
    for file in files:
      if file.endswith(".csv"):
        filepath = os.path.join(root, file)
        grandparent_folder = os.path.basename(parent_folder) 
        parent_folder_name = os.path.basename(os.path.dirname(root))
        df_name = file[:-4]
        try:
          df = pd.read_csv(filepath)
          dataframes[df_name] = df
          print(f"Successfully read {file} into the dataframe named {df_name}")
        except Exception as e:
          print(f"ERROR: Failed to read {file}: {e}")
  return dataframes

if __name__ == "__main__":
  parent_folder = "../data/raw/itineraries_csv"  # Replace with the actual path
  dataframes = data_reading(parent_folder)
# Out:
# Successfully read ATL_itineraries_aa.csv into the dataframe named ATL_itineraries_aa
# Successfully read ATL_itineraries_ab.csv into the dataframe named ATL_itineraries_ab
# Successfully read ATL_itineraries_ac.csv into the dataframe named ATL_itineraries_ac
# Successfully read ATL_itineraries_ad.csv into the dataframe named ATL_itineraries_ad
# Successfully read ATL_itineraries_ae.csv into the dataframe named ATL_itineraries_ae
# Successfully read ATL_itineraries_af.csv into the dataframe named ATL_itineraries_af
# Successfully read ATL_itineraries_ag.csv into the dataframe named ATL_itineraries_ag
# Successfully read ATL_itineraries_ah.csv into the dataframe named ATL_itineraries_ah
# Successfully read ATL_itineraries_ai.csv into the dataframe named ATL_itineraries_ai
# Successfully read ATL_itineraries_aj.csv into the dataframe named ATL_itineraries_aj
# Successfully read ATL_itineraries_ak.csv into the dataframe named ATL_itineraries_ak
# Successfully read ATL_itineraries_al.csv into the dataframe named ATL_itineraries_al
# Successfully read ATL_itineraries_am.csv into the dataframe named ATL_itineraries_am
# Successfully read ATL_itineraries_an.csv into the dataframe named ATL_itineraries_an
# Successfully read ATL_itineraries_ao.csv into the dataframe named ATL_itineraries_ao
# Successfully read ATL_itineraries_ap.csv into the dataframe named ATL_itineraries_ap
# Successfully read ATL_itineraries_aq.csv into the dataframe named ATL_itineraries_aq
# Successfully read ATL_itineraries_ar.csv into the dataframe named ATL_itineraries_ar
# Successfully read ATL_itineraries_as.csv into the dataframe named ATL_itineraries_as
# Successfully read ATL_itineraries_at.csv into the dataframe named ATL_itineraries_at
# Successfully read ATL_itineraries_au.csv into the dataframe named ATL_itineraries_au
# Successfully read ATL_itineraries_av.csv into the dataframe named ATL_itineraries_av
# Successfully read ATL_itineraries_aw.csv into the dataframe named ATL_itineraries_aw
# Successfully read ATL_itineraries_ax.csv into the dataframe named ATL_itineraries_ax
# Successfully read ATL_itineraries_ay.csv into the dataframe named ATL_itineraries_ay
# Successfully read ATL_itineraries_az.csv into the dataframe named ATL_itineraries_az
# Successfully read ATL_itineraries_ba.csv into the dataframe named ATL_itineraries_ba
# Successfully read ATL_itineraries_bb.csv into the dataframe named ATL_itineraries_bb
# Successfully read ATL_itineraries_bc.csv into the dataframe named ATL_itineraries_bc
# Successfully read ATL_itineraries_bd.csv into the dataframe named ATL_itineraries_bd
# Successfully read ATL_itineraries_be.csv into the dataframe named ATL_itineraries_be
# Successfully read ATL_itineraries_bf.csv into the dataframe named ATL_itineraries_bf
# Successfully read ATL_itineraries_bg.csv into the dataframe named ATL_itineraries_bg
# Successfully read ATL_itineraries_bh.csv into the dataframe named ATL_itineraries_bh
# Successfully read ATL_itineraries_bi.csv into the dataframe named ATL_itineraries_bi
# Successfully read ATL_itineraries_bj.csv into the dataframe named ATL_itineraries_bj
# Successfully read ATL_itineraries_bk.csv into the dataframe named ATL_itineraries_bk
# Successfully read ATL_itineraries_bl.csv into the dataframe named ATL_itineraries_bl
# Successfully read ATL_itineraries_bm.csv into the dataframe named ATL_itineraries_bm
# Successfully read ATL_itineraries_bn.csv into the dataframe named ATL_itineraries_bn
# Successfully read ATL_itineraries_bo.csv into the dataframe named ATL_itineraries_bo
# Successfully read ATL_itineraries_bp.csv into the dataframe named ATL_itineraries_bp
# Successfully read ATL_itineraries_bq.csv into the dataframe named ATL_itineraries_bq
# Successfully read ATL_itineraries_br.csv into the dataframe named ATL_itineraries_br
# Successfully read ATL_itineraries_bs.csv into the dataframe named ATL_itineraries_bs
# Successfully read ATL_itineraries_bt.csv into the dataframe named ATL_itineraries_bt
# Successfully read ATL_itineraries_bu.csv into the dataframe named ATL_itineraries_bu
# Successfully read ATL_itineraries_bv.csv into the dataframe named ATL_itineraries_bv
# Successfully read ATL_itineraries_bw.csv into the dataframe named ATL_itineraries_bw
# Successfully read ATL_itineraries_bx.csv into the dataframe named ATL_itineraries_bx
# Successfully read ATL_itineraries_by.csv into the dataframe named ATL_itineraries_by
# Successfully read ATL_itineraries_bz.csv into the dataframe named ATL_itineraries_bz
# Successfully read ATL_itineraries_ca.csv into the dataframe named ATL_itineraries_ca
# Successfully read ATL_itineraries_cb.csv into the dataframe named ATL_itineraries_cb
# Successfully read ATL_itineraries_cc.csv into the dataframe named ATL_itineraries_cc
# Successfully read ATL_itineraries_cd.csv into the dataframe named ATL_itineraries_cd
# Successfully read ATL_itineraries_ce.csv into the dataframe named ATL_itineraries_ce
# Successfully read ATL_itineraries_cf.csv into the dataframe named ATL_itineraries_cf
# Successfully read ATL_itineraries_cg.csv into the dataframe named ATL_itineraries_cg
# Successfully read ATL_itineraries_ch.csv into the dataframe named ATL_itineraries_ch
# Successfully read ATL_itineraries_ci.csv into the dataframe named ATL_itineraries_ci
# Successfully read ATL_itineraries_cj.csv into the dataframe named ATL_itineraries_cj
# Successfully read ATL_itineraries_ck.csv into the dataframe named ATL_itineraries_ck
# Successfully read ATL_itineraries_cl.csv into the dataframe named ATL_itineraries_cl
# Successfully read ATL_itineraries_cm.csv into the dataframe named ATL_itineraries_cm
# Successfully read ATL_itineraries_cn.csv into the dataframe named ATL_itineraries_cn
# Successfully read ATL_itineraries_co.csv into the dataframe named ATL_itineraries_co
# Successfully read ATL_itineraries_cp.csv into the dataframe named ATL_itineraries_cp
# Successfully read ATL_itineraries_cq.csv into the dataframe named ATL_itineraries_cq
# Successfully read ATL_itineraries_cr.csv into the dataframe named ATL_itineraries_cr
# Successfully read ATL_itineraries_cs.csv into the dataframe named ATL_itineraries_cs
# Successfully read ATL_itineraries_ct.csv into the dataframe named ATL_itineraries_ct
# Successfully read ATL_itineraries_cu.csv into the dataframe named ATL_itineraries_cu
# Successfully read ATL_itineraries_cv.csv into the dataframe named ATL_itineraries_cv
# Successfully read ATL_itineraries_cw.csv into the dataframe named ATL_itineraries_cw
# Successfully read ATL_itineraries_cx.csv into the dataframe named ATL_itineraries_cx
# Successfully read ATL_itineraries_cy.csv into the dataframe named ATL_itineraries_cy
# Successfully read ATL_itineraries_cz.csv into the dataframe named ATL_itineraries_cz
# Successfully read ATL_itineraries_da.csv into the dataframe named ATL_itineraries_da
# Successfully read ATL_itineraries_db.csv into the dataframe named ATL_itineraries_db
# Successfully read ATL_itineraries_dc.csv into the dataframe named ATL_itineraries_dc
# Successfully read ATL_itineraries_dd.csv into the dataframe named ATL_itineraries_dd
# Successfully read ATL_itineraries_de.csv into the dataframe named ATL_itineraries_de
# Successfully read ATL_itineraries_df.csv into the dataframe named ATL_itineraries_df
# Successfully read ATL_itineraries_dg.csv into the dataframe named ATL_itineraries_dg
# Successfully read ATL_itineraries_dh.csv into the dataframe named ATL_itineraries_dh
# Successfully read ATL_itineraries_di.csv into the dataframe named ATL_itineraries_di
# Successfully read ATL_itineraries_dj.csv into the dataframe named ATL_itineraries_dj
# Successfully read ATL_itineraries_dk.csv into the dataframe named ATL_itineraries_dk
# Successfully read ATL_itineraries_dl.csv into the dataframe named ATL_itineraries_dl
# Successfully read ATL_itineraries_dm.csv into the dataframe named ATL_itineraries_dm
# Successfully read ATL_itineraries_dn.csv into the dataframe named ATL_itineraries_dn
# Successfully read ATL_itineraries_do.csv into the dataframe named ATL_itineraries_do
# Successfully read ATL_itineraries_dp.csv into the dataframe named ATL_itineraries_dp
# Successfully read ATL_itineraries_dq.csv into the dataframe named ATL_itineraries_dq
# Successfully read ATL_itineraries_dr.csv into the dataframe named ATL_itineraries_dr
# Successfully read ATL_itineraries_ds.csv into the dataframe named ATL_itineraries_ds
# Successfully read ATL_itineraries_dt.csv into the dataframe named ATL_itineraries_dt
# Successfully read ATL_itineraries_du.csv into the dataframe named ATL_itineraries_du
# Successfully read ATL_itineraries_dv.csv into the dataframe named ATL_itineraries_dv
# Successfully read ATL_itineraries_dw.csv into the dataframe named ATL_itineraries_dw
# Successfully read ATL_itineraries_dx.csv into the dataframe named ATL_itineraries_dx
# Successfully read ATL_itineraries_dy.csv into the dataframe named ATL_itineraries_dy
# Successfully read ATL_itineraries_dz.csv into the dataframe named ATL_itineraries_dz
# Successfully read ATL_itineraries_ea.csv into the dataframe named ATL_itineraries_ea
# Successfully read ATL_itineraries_eb.csv into the dataframe named ATL_itineraries_eb
# Successfully read ATL_itineraries_ec.csv into the dataframe named ATL_itineraries_ec
# Successfully read ATL_itineraries_ed.csv into the dataframe named ATL_itineraries_ed
# Successfully read ATL_itineraries_ee.csv into the dataframe named ATL_itineraries_ee
# Successfully read ATL_itineraries_ef.csv into the dataframe named ATL_itineraries_ef
# Successfully read ATL_itineraries_eg.csv into the dataframe named ATL_itineraries_eg
# Successfully read ATL_itineraries_eh.csv into the dataframe named ATL_itineraries_eh
# Successfully read ATL_itineraries_ei.csv into the dataframe named ATL_itineraries_ei
# Successfully read ATL_itineraries_ej.csv into the dataframe named ATL_itineraries_ej
# Successfully read ATL_itineraries_ek.csv into the dataframe named ATL_itineraries_ek
# Successfully read ATL_itineraries_el.csv into the dataframe named ATL_itineraries_el
# Successfully read ATL_itineraries_em.csv into the dataframe named ATL_itineraries_em
# Successfully read ATL_itineraries_en.csv into the dataframe named ATL_itineraries_en
# Successfully read ATL_itineraries_eo.csv into the dataframe named ATL_itineraries_eo
# Successfully read ATL_itineraries_ep.csv into the dataframe named ATL_itineraries_ep
# Successfully read ATL_itineraries_eq.csv into the dataframe named ATL_itineraries_eq
# Successfully read ATL_itineraries_er.csv into the dataframe named ATL_itineraries_er
# Successfully read ATL_itineraries_es.csv into the dataframe named ATL_itineraries_es
# Successfully read ATL_itineraries_et.csv into the dataframe named ATL_itineraries_et
# Successfully read ATL_itineraries_eu.csv into the dataframe named ATL_itineraries_eu
# Successfully read ATL_itineraries_ev.csv into the dataframe named ATL_itineraries_ev
# Successfully read ATL_itineraries_ew.csv into the dataframe named ATL_itineraries_ew
# Successfully read ATL_itineraries_ex.csv into the dataframe named ATL_itineraries_ex
# Successfully read ATL_itineraries_ey.csv into the dataframe named ATL_itineraries_ey
# Successfully read ATL_itineraries_ez.csv into the dataframe named ATL_itineraries_ez
# Successfully read ATL_itineraries_fa.csv into the dataframe named ATL_itineraries_fa
# Successfully read ATL_itineraries_fb.csv into the dataframe named ATL_itineraries_fb
# Successfully read ATL_itineraries_fc.csv into the dataframe named ATL_itineraries_fc
# Successfully read ATL_itineraries_fd.csv into the dataframe named ATL_itineraries_fd
# Successfully read ATL_itineraries_fe.csv into the dataframe named ATL_itineraries_fe
# Successfully read ATL_itineraries_ff.csv into the dataframe named ATL_itineraries_ff
# Successfully read ATL_itineraries_fg.csv into the dataframe named ATL_itineraries_fg
# Successfully read ATL_itineraries_fh.csv into the dataframe named ATL_itineraries_fh
# Successfully read ATL_itineraries_fi.csv into the dataframe named ATL_itineraries_fi
# Successfully read ATL_itineraries_fj.csv into the dataframe named ATL_itineraries_fj
# Successfully read ATL_itineraries_fk.csv into the dataframe named ATL_itineraries_fk
# Successfully read ATL_itineraries_fl.csv into the dataframe named ATL_itineraries_fl
# Successfully read ATL_itineraries_fm.csv into the dataframe named ATL_itineraries_fm
# Successfully read ATL_itineraries_fn.csv into the dataframe named ATL_itineraries_fn
# Successfully read ATL_itineraries_fo.csv into the dataframe named ATL_itineraries_fo
# Successfully read ATL_itineraries_fp.csv into the dataframe named ATL_itineraries_fp
# Successfully read ATL_itineraries_fq.csv into the dataframe named ATL_itineraries_fq
# Successfully read ATL_itineraries_fr.csv into the dataframe named ATL_itineraries_fr
# Successfully read ATL_itineraries_fs.csv into the dataframe named ATL_itineraries_fs
# Successfully read ATL_itineraries_ft.csv into the dataframe named ATL_itineraries_ft
# Successfully read ATL_itineraries_fu.csv into the dataframe named ATL_itineraries_fu
# Successfully read ATL_itineraries_fv.csv into the dataframe named ATL_itineraries_fv
# Successfully read ATL_itineraries_fw.csv into the dataframe named ATL_itineraries_fw
# Successfully read ATL_itineraries_fx.csv into the dataframe named ATL_itineraries_fx
# Successfully read ATL_itineraries_fy.csv into the dataframe named ATL_itineraries_fy
# Successfully read ATL_itineraries_fz.csv into the dataframe named ATL_itineraries_fz
# Successfully read ATL_itineraries_ga.csv into the dataframe named ATL_itineraries_ga
# Successfully read ATL_itineraries_gb.csv into the dataframe named ATL_itineraries_gb
# Successfully read ATL_itineraries_gc.csv into the dataframe named ATL_itineraries_gc
# Successfully read ATL_itineraries_gd.csv into the dataframe named ATL_itineraries_gd
# Successfully read ATL_itineraries_ge.csv into the dataframe named ATL_itineraries_ge
# Successfully read ATL_itineraries_gf.csv into the dataframe named ATL_itineraries_gf
# Successfully read ATL_itineraries_gg.csv into the dataframe named ATL_itineraries_gg
# Successfully read ATL_itineraries_gh.csv into the dataframe named ATL_itineraries_gh
# Successfully read ATL_itineraries_gi.csv into the dataframe named ATL_itineraries_gi
# Successfully read ATL_itineraries_gj.csv into the dataframe named ATL_itineraries_gj
# Successfully read ATL_itineraries_gk.csv into the dataframe named ATL_itineraries_gk
# Successfully read ATL_itineraries_gl.csv into the dataframe named ATL_itineraries_gl
# Successfully read ATL_itineraries_gm.csv into the dataframe named ATL_itineraries_gm
# Successfully read ATL_itineraries_gn.csv into the dataframe named ATL_itineraries_gn
# Successfully read ATL_itineraries_go.csv into the dataframe named ATL_itineraries_go
# Successfully read ATL_itineraries_gp.csv into the dataframe named ATL_itineraries_gp
# Successfully read ATL_itineraries_gq.csv into the dataframe named ATL_itineraries_gq
# Successfully read ATL_itineraries_gr.csv into the dataframe named ATL_itineraries_gr
# Successfully read ATL_itineraries_gs.csv into the dataframe named ATL_itineraries_gs
# Successfully read ATL_itineraries_gt.csv into the dataframe named ATL_itineraries_gt
# Successfully read ATL_itineraries_gu.csv into the dataframe named ATL_itineraries_gu
# Successfully read ATL_itineraries_gv.csv into the dataframe named ATL_itineraries_gv
# Successfully read ATL_itineraries_gw.csv into the dataframe named ATL_itineraries_gw
# Successfully read ATL_itineraries_gx.csv into the dataframe named ATL_itineraries_gx
# Successfully read ATL_itineraries_gy.csv into the dataframe named ATL_itineraries_gy
# Successfully read ATL_itineraries_gz.csv into the dataframe named ATL_itineraries_gz
# Successfully read ATL_itineraries_ha.csv into the dataframe named ATL_itineraries_ha
# Successfully read ATL_itineraries_hb.csv into the dataframe named ATL_itineraries_hb
# Successfully read ATL_itineraries_hc.csv into the dataframe named ATL_itineraries_hc
# Successfully read ATL_itineraries_hd.csv into the dataframe named ATL_itineraries_hd
# Successfully read ATL_itineraries_he.csv into the dataframe named ATL_itineraries_he
# Successfully read ATL_itineraries_hf.csv into the dataframe named ATL_itineraries_hf
# Successfully read ATL_itineraries_hg.csv into the dataframe named ATL_itineraries_hg
# Successfully read ATL_itineraries_hh.csv into the dataframe named ATL_itineraries_hh
# Successfully read ATL_itineraries_hi.csv into the dataframe named ATL_itineraries_hi
# Successfully read ATL_itineraries_hj.csv into the dataframe named ATL_itineraries_hj
# Successfully read ATL_itineraries_hk.csv into the dataframe named ATL_itineraries_hk
# Successfully read ATL_itineraries_hl.csv into the dataframe named ATL_itineraries_hl
# Successfully read ATL_itineraries_hm.csv into the dataframe named ATL_itineraries_hm
# Successfully read ATL_itineraries_hn.csv into the dataframe named ATL_itineraries_hn
# Successfully read ATL_itineraries_ho.csv into the dataframe named ATL_itineraries_ho
# Successfully read ATL_itineraries_hp.csv into the dataframe named ATL_itineraries_hp
# Successfully read ATL_itineraries_hq.csv into the dataframe named ATL_itineraries_hq
# Successfully read ATL_itineraries_hr.csv into the dataframe named ATL_itineraries_hr
# Successfully read ATL_itineraries_hs.csv into the dataframe named ATL_itineraries_hs
# Successfully read ATL_itineraries_ht.csv into the dataframe named ATL_itineraries_ht
# Successfully read ATL_itineraries_hu.csv into the dataframe named ATL_itineraries_hu
# Successfully read ATL_itineraries_hv.csv into the dataframe named ATL_itineraries_hv
# Successfully read ATL_itineraries_hw.csv into the dataframe named ATL_itineraries_hw
# Successfully read ATL_itineraries_hx.csv into the dataframe named ATL_itineraries_hx
# Successfully read ATL_itineraries_hy.csv into the dataframe named ATL_itineraries_hy
# Successfully read ATL_itineraries_hz.csv into the dataframe named ATL_itineraries_hz
# Successfully read ATL_itineraries_ia.csv into the dataframe named ATL_itineraries_ia
# Successfully read ATL_itineraries_ib.csv into the dataframe named ATL_itineraries_ib
# Successfully read ATL_itineraries_ic.csv into the dataframe named ATL_itineraries_ic
# Successfully read ATL_itineraries_id.csv into the dataframe named ATL_itineraries_id
# Successfully read ATL_itineraries_ie.csv into the dataframe named ATL_itineraries_ie
# Successfully read ATL_itineraries_if.csv into the dataframe named ATL_itineraries_if
# Successfully read ATL_itineraries_ig.csv into the dataframe named ATL_itineraries_ig
# Successfully read ATL_itineraries_ih.csv into the dataframe named ATL_itineraries_ih
# Successfully read ATL_itineraries_ii.csv into the dataframe named ATL_itineraries_ii
# Successfully read ATL_itineraries_ij.csv into the dataframe named ATL_itineraries_ij
# Successfully read ATL_itineraries_ik.csv into the dataframe named ATL_itineraries_ik
# Successfully read ATL_itineraries_il.csv into the dataframe named ATL_itineraries_il
# Successfully read ATL_itineraries_im.csv into the dataframe named ATL_itineraries_im
# Successfully read ATL_itineraries_in.csv into the dataframe named ATL_itineraries_in
# Successfully read ATL_itineraries_io.csv into the dataframe named ATL_itineraries_io
# Successfully read ATL_itineraries_ip.csv into the dataframe named ATL_itineraries_ip
# Successfully read ATL_itineraries_iq.csv into the dataframe named ATL_itineraries_iq
# Successfully read ATL_itineraries_ir.csv into the dataframe named ATL_itineraries_ir
# Successfully read ATL_itineraries_is.csv into the dataframe named ATL_itineraries_is
# Successfully read ATL_itineraries_it.csv into the dataframe named ATL_itineraries_it
# Successfully read ATL_itineraries_iu.csv into the dataframe named ATL_itineraries_iu
# Successfully read ATL_itineraries_iv.csv into the dataframe named ATL_itineraries_iv
# Successfully read ATL_itineraries_iw.csv into the dataframe named ATL_itineraries_iw
# Successfully read ATL_itineraries_ix.csv into the dataframe named ATL_itineraries_ix
# Successfully read ATL_itineraries_iy.csv into the dataframe named ATL_itineraries_iy
# Successfully read ATL_itineraries_iz.csv into the dataframe named ATL_itineraries_iz
# Successfully read ATL_itineraries_ja.csv into the dataframe named ATL_itineraries_ja
# Successfully read ATL_itineraries_jb.csv into the dataframe named ATL_itineraries_jb
# Successfully read ATL_itineraries_jc.csv into the dataframe named ATL_itineraries_jc
# Successfully read ATL_itineraries_jd.csv into the dataframe named ATL_itineraries_jd
# Successfully read ATL_itineraries_je.csv into the dataframe named ATL_itineraries_je
# Successfully read ATL_itineraries_jf.csv into the dataframe named ATL_itineraries_jf
# Successfully read ATL_itineraries_jg.csv into the dataframe named ATL_itineraries_jg
# Successfully read ATL_itineraries_jh.csv into the dataframe named ATL_itineraries_jh
# Successfully read ATL_itineraries_ji.csv into the dataframe named ATL_itineraries_ji
# Successfully read ATL_itineraries_jj.csv into the dataframe named ATL_itineraries_jj
# Successfully read ATL_itineraries_jk.csv into the dataframe named ATL_itineraries_jk
# Successfully read ATL_itineraries_jl.csv into the dataframe named ATL_itineraries_jl
# Successfully read ATL_itineraries_jm.csv into the dataframe named ATL_itineraries_jm
# Successfully read ATL_itineraries_jn.csv into the dataframe named ATL_itineraries_jn
# Successfully read ATL_itineraries_jo.csv into the dataframe named ATL_itineraries_jo
# Successfully read ATL_itineraries_jp.csv into the dataframe named ATL_itineraries_jp
# Successfully read ATL_itineraries_jq.csv into the dataframe named ATL_itineraries_jq
# Successfully read ATL_itineraries_jr.csv into the dataframe named ATL_itineraries_jr
# Successfully read ATL_itineraries_js.csv into the dataframe named ATL_itineraries_js
# Successfully read ATL_itineraries_jt.csv into the dataframe named ATL_itineraries_jt
# Successfully read ATL_itineraries_ju.csv into the dataframe named ATL_itineraries_ju
# Successfully read ATL_itineraries_jv.csv into the dataframe named ATL_itineraries_jv
# Successfully read ATL_itineraries_jw.csv into the dataframe named ATL_itineraries_jw
# Successfully read ATL_itineraries_jx.csv into the dataframe named ATL_itineraries_jx
# Successfully read ATL_itineraries_jy.csv into the dataframe named ATL_itineraries_jy
# Successfully read ATL_itineraries_jz.csv into the dataframe named ATL_itineraries_jz
# Successfully read ATL_itineraries_ka.csv into the dataframe named ATL_itineraries_ka
# Successfully read ATL_itineraries_kb.csv into the dataframe named ATL_itineraries_kb
# Successfully read ATL_itineraries_kc.csv into the dataframe named ATL_itineraries_kc
# Successfully read ATL_itineraries_kd.csv into the dataframe named ATL_itineraries_kd
# Successfully read ATL_itineraries_ke.csv into the dataframe named ATL_itineraries_ke
# Successfully read ATL_itineraries_kf.csv into the dataframe named ATL_itineraries_kf
# Successfully read ATL_itineraries_kg.csv into the dataframe named ATL_itineraries_kg
# Successfully read ATL_itineraries_kh.csv into the dataframe named ATL_itineraries_kh
# Successfully read ATL_itineraries_ki.csv into the dataframe named ATL_itineraries_ki
# Successfully read ATL_itineraries_kj.csv into the dataframe named ATL_itineraries_kj
# Successfully read ATL_itineraries_kk.csv into the dataframe named ATL_itineraries_kk
# Successfully read ATL_itineraries_kl.csv into the dataframe named ATL_itineraries_kl
# Successfully read ATL_itineraries_km.csv into the dataframe named ATL_itineraries_km
# Successfully read ATL_itineraries_kn.csv into the dataframe named ATL_itineraries_kn
# Successfully read ATL_itineraries_ko.csv into the dataframe named ATL_itineraries_ko
# Successfully read ATL_itineraries_kp.csv into the dataframe named ATL_itineraries_kp
# Successfully read ATL_itineraries_kq.csv into the dataframe named ATL_itineraries_kq
# Successfully read ATL_itineraries_kr.csv into the dataframe named ATL_itineraries_kr
# Successfully read ATL_itineraries_ks.csv into the dataframe named ATL_itineraries_ks
# Successfully read ATL_itineraries_kt.csv into the dataframe named ATL_itineraries_kt
# Successfully read ATL_itineraries_ku.csv into the dataframe named ATL_itineraries_ku
# Successfully read ATL_itineraries_kv.csv into the dataframe named ATL_itineraries_kv
# Successfully read ATL_itineraries_kw.csv into the dataframe named ATL_itineraries_kw
# Successfully read ATL_itineraries_kx.csv into the dataframe named ATL_itineraries_kx
# Successfully read ATL_itineraries_ky.csv into the dataframe named ATL_itineraries_ky
# Successfully read ATL_itineraries_kz.csv into the dataframe named ATL_itineraries_kz
# Successfully read ATL_itineraries_la.csv into the dataframe named ATL_itineraries_la
# Successfully read ATL_itineraries_lb.csv into the dataframe named ATL_itineraries_lb
# Successfully read ATL_itineraries_lc.csv into the dataframe named ATL_itineraries_lc
# Successfully read ATL_itineraries_ld.csv into the dataframe named ATL_itineraries_ld
# Successfully read ATL_itineraries_le.csv into the dataframe named ATL_itineraries_le
# Successfully read ATL_itineraries_lf.csv into the dataframe named ATL_itineraries_lf
# Successfully read ATL_itineraries_lg.csv into the dataframe named ATL_itineraries_lg
# Successfully read ATL_itineraries_lh.csv into the dataframe named ATL_itineraries_lh
# Successfully read ATL_itineraries_li.csv into the dataframe named ATL_itineraries_li
# Successfully read ATL_itineraries_lj.csv into the dataframe named ATL_itineraries_lj
# Successfully read ATL_itineraries_lk.csv into the dataframe named ATL_itineraries_lk
# Successfully read ATL_itineraries_ll.csv into the dataframe named ATL_itineraries_ll
# Successfully read ATL_itineraries_lm.csv into the dataframe named ATL_itineraries_lm
# Successfully read ATL_itineraries_ln.csv into the dataframe named ATL_itineraries_ln
# Successfully read ATL_itineraries_lo.csv into the dataframe named ATL_itineraries_lo
# Successfully read ATL_itineraries_lp.csv into the dataframe named ATL_itineraries_lp
# Successfully read ATL_itineraries_lq.csv into the dataframe named ATL_itineraries_lq
# Successfully read ATL_itineraries_lr.csv into the dataframe named ATL_itineraries_lr
# Successfully read ATL_itineraries_ls.csv into the dataframe named ATL_itineraries_ls
# Successfully read ATL_itineraries_lt.csv into the dataframe named ATL_itineraries_lt
# Successfully read ATL_itineraries_lu.csv into the dataframe named ATL_itineraries_lu
# Successfully read ATL_itineraries_lv.csv into the dataframe named ATL_itineraries_lv
# Successfully read ATL_itineraries_lw.csv into the dataframe named ATL_itineraries_lw
# Successfully read ATL_itineraries_lx.csv into the dataframe named ATL_itineraries_lx
# Successfully read ATL_itineraries_ly.csv into the dataframe named ATL_itineraries_ly
# Successfully read ATL_itineraries_lz.csv into the dataframe named ATL_itineraries_lz
# Successfully read ATL_itineraries_ma.csv into the dataframe named ATL_itineraries_ma
# Successfully read ATL_itineraries_mb.csv into the dataframe named ATL_itineraries_mb
# Successfully read ATL_itineraries_mc.csv into the dataframe named ATL_itineraries_mc
# Successfully read ATL_itineraries_md.csv into the dataframe named ATL_itineraries_md
# Successfully read ATL_itineraries_me.csv into the dataframe named ATL_itineraries_me
# Successfully read ATL_itineraries_mf.csv into the dataframe named ATL_itineraries_mf
# Successfully read ATL_itineraries_mg.csv into the dataframe named ATL_itineraries_mg
# Successfully read ATL_itineraries_mh.csv into the dataframe named ATL_itineraries_mh
# Successfully read ATL_itineraries_mi.csv into the dataframe named ATL_itineraries_mi
# Successfully read ATL_itineraries_mj.csv into the dataframe named ATL_itineraries_mj
# Successfully read ATL_itineraries_mk.csv into the dataframe named ATL_itineraries_mk
# Successfully read ATL_itineraries_ml.csv into the dataframe named ATL_itineraries_ml
# Successfully read ATL_itineraries_mm.csv into the dataframe named ATL_itineraries_mm
# Successfully read ATL_itineraries_mn.csv into the dataframe named ATL_itineraries_mn
# Successfully read ATL_itineraries_mo.csv into the dataframe named ATL_itineraries_mo
# Successfully read ATL_itineraries_mp.csv into the dataframe named ATL_itineraries_mp
# Successfully read ATL_itineraries_mq.csv into the dataframe named ATL_itineraries_mq
# Successfully read ATL_itineraries_mr.csv into the dataframe named ATL_itineraries_mr
# Successfully read ATL_itineraries_ms.csv into the dataframe named ATL_itineraries_ms
# Successfully read ATL_itineraries_mt.csv into the dataframe named ATL_itineraries_mt
# Successfully read ATL_itineraries_mu.csv into the dataframe named ATL_itineraries_mu
# Successfully read ATL_itineraries_mv.csv into the dataframe named ATL_itineraries_mv
# Successfully read ATL_itineraries_mw.csv into the dataframe named ATL_itineraries_mw
# Successfully read ATL_itineraries_mx.csv into the dataframe named ATL_itineraries_mx
# Successfully read ATL_itineraries_my.csv into the dataframe named ATL_itineraries_my
# Successfully read ATL_itineraries_mz.csv into the dataframe named ATL_itineraries_mz
# Successfully read ATL_itineraries_na.csv into the dataframe named ATL_itineraries_na
# Successfully read ATL_itineraries_nb.csv into the dataframe named ATL_itineraries_nb
# Successfully read ATL_itineraries_nc.csv into the dataframe named ATL_itineraries_nc
# Successfully read ATL_itineraries_nd.csv into the dataframe named ATL_itineraries_nd
# Successfully read ATL_itineraries_ne.csv into the dataframe named ATL_itineraries_ne
# Successfully read ATL_itineraries_nf.csv into the dataframe named ATL_itineraries_nf
# Successfully read ATL_itineraries_ng.csv into the dataframe named ATL_itineraries_ng
# Successfully read ATL_itineraries_nh.csv into the dataframe named ATL_itineraries_nh
# Successfully read ATL_itineraries_ni.csv into the dataframe named ATL_itineraries_ni
# Successfully read ATL_itineraries_nj.csv into the dataframe named ATL_itineraries_nj
# Successfully read ATL_itineraries_nk.csv into the dataframe named ATL_itineraries_nk
# Successfully read ATL_itineraries_nl.csv into the dataframe named ATL_itineraries_nl
# Successfully read ATL_itineraries_nm.csv into the dataframe named ATL_itineraries_nm
# Successfully read ATL_itineraries_nn.csv into the dataframe named ATL_itineraries_nn
# Successfully read ATL_itineraries_no.csv into the dataframe named ATL_itineraries_no
# Successfully read ATL_itineraries_np.csv into the dataframe named ATL_itineraries_np
# Successfully read ATL_itineraries_nq.csv into the dataframe named ATL_itineraries_nq
# Successfully read ATL_itineraries_nr.csv into the dataframe named ATL_itineraries_nr
# Successfully read ATL_itineraries_ns.csv into the dataframe named ATL_itineraries_ns
# Successfully read ATL_itineraries_nt.csv into the dataframe named ATL_itineraries_nt
# Successfully read ATL_itineraries_nu.csv into the dataframe named ATL_itineraries_nu
# Successfully read ATL_itineraries_nv.csv into the dataframe named ATL_itineraries_nv
# Successfully read ATL_itineraries_nw.csv into the dataframe named ATL_itineraries_nw
# Successfully read ATL_itineraries_nx.csv into the dataframe named ATL_itineraries_nx
# Successfully read ATL_itineraries_ny.csv into the dataframe named ATL_itineraries_ny
# Successfully read ATL_itineraries_nz.csv into the dataframe named ATL_itineraries_nz
# Successfully read ATL_itineraries_oa.csv into the dataframe named ATL_itineraries_oa
# Successfully read ATL_itineraries_ob.csv into the dataframe named ATL_itineraries_ob
# Successfully read ATL_itineraries_oc.csv into the dataframe named ATL_itineraries_oc
# Successfully read ATL_itineraries_od.csv into the dataframe named ATL_itineraries_od
# Successfully read ATL_itineraries_oe.csv into the dataframe named ATL_itineraries_oe
# Successfully read ATL_itineraries_of.csv into the dataframe named ATL_itineraries_of
# Successfully read ATL_itineraries_og.csv into the dataframe named ATL_itineraries_og
# Successfully read ATL_itineraries_oh.csv into the dataframe named ATL_itineraries_oh
# Successfully read ATL_itineraries_oi.csv into the dataframe named ATL_itineraries_oi
# Successfully read ATL_itineraries_oj.csv into the dataframe named ATL_itineraries_oj
# Successfully read ATL_itineraries_ok.csv into the dataframe named ATL_itineraries_ok
# Successfully read ATL_itineraries_ol.csv into the dataframe named ATL_itineraries_ol
# Successfully read ATL_itineraries_om.csv into the dataframe named ATL_itineraries_om
# Successfully read ATL_itineraries_on.csv into the dataframe named ATL_itineraries_on
# Successfully read ATL_itineraries_oo.csv into the dataframe named ATL_itineraries_oo
# Successfully read ATL_itineraries_op.csv into the dataframe named ATL_itineraries_op
# Successfully read ATL_itineraries_oq.csv into the dataframe named ATL_itineraries_oq
# Successfully read ATL_itineraries_or.csv into the dataframe named ATL_itineraries_or
# Successfully read ATL_itineraries_os.csv into the dataframe named ATL_itineraries_os
# Successfully read ATL_itineraries_ot.csv into the dataframe named ATL_itineraries_ot
# Successfully read ATL_itineraries_ou.csv into the dataframe named ATL_itineraries_ou
# Successfully read ATL_itineraries_ov.csv into the dataframe named ATL_itineraries_ov
# Successfully read ATL_itineraries_ow.csv into the dataframe named ATL_itineraries_ow
# Successfully read ATL_itineraries_ox.csv into the dataframe named ATL_itineraries_ox
# Successfully read ATL_itineraries_oy.csv into the dataframe named ATL_itineraries_oy
# Successfully read ATL_itineraries_oz.csv into the dataframe named ATL_itineraries_oz
# Successfully read ATL_itineraries_pa.csv into the dataframe named ATL_itineraries_pa
# Successfully read ATL_itineraries_pb.csv into the dataframe named ATL_itineraries_pb
# Successfully read ATL_itineraries_pc.csv into the dataframe named ATL_itineraries_pc
# Successfully read ATL_itineraries_pd.csv into the dataframe named ATL_itineraries_pd
# Successfully read ATL_itineraries_pe.csv into the dataframe named ATL_itineraries_pe
# Successfully read ATL_itineraries_pf.csv into the dataframe named ATL_itineraries_pf
# Successfully read ATL_itineraries_pg.csv into the dataframe named ATL_itineraries_pg
# Successfully read ATL_itineraries_ph.csv into the dataframe named ATL_itineraries_ph
# Successfully read ATL_itineraries_pi.csv into the dataframe named ATL_itineraries_pi
# Successfully read ATL_itineraries_pj.csv into the dataframe named ATL_itineraries_pj
# Successfully read ATL_itineraries_pk.csv into the dataframe named ATL_itineraries_pk
# Successfully read ATL_itineraries_pl.csv into the dataframe named ATL_itineraries_pl
# Successfully read ATL_itineraries_pm.csv into the dataframe named ATL_itineraries_pm
# Successfully read ATL_itineraries_pn.csv into the dataframe named ATL_itineraries_pn
# Successfully read ATL_itineraries_po.csv into the dataframe named ATL_itineraries_po
# Successfully read ATL_itineraries_pp.csv into the dataframe named ATL_itineraries_pp
# Successfully read ATL_itineraries_pq.csv into the dataframe named ATL_itineraries_pq
# Successfully read ATL_itineraries_pr.csv into the dataframe named ATL_itineraries_pr
# Successfully read ATL_itineraries_ps.csv into the dataframe named ATL_itineraries_ps
# Successfully read ATL_itineraries_pt.csv into the dataframe named ATL_itineraries_pt
# Successfully read ATL_itineraries_pu.csv into the dataframe named ATL_itineraries_pu
# Successfully read ATL_itineraries_pv.csv into the dataframe named ATL_itineraries_pv
# Successfully read ATL_itineraries_pw.csv into the dataframe named ATL_itineraries_pw
# Successfully read ATL_itineraries_px.csv into the dataframe named ATL_itineraries_px
# Successfully read ATL_itineraries_py.csv into the dataframe named ATL_itineraries_py
# Successfully read ATL_itineraries_pz.csv into the dataframe named ATL_itineraries_pz
# Successfully read ATL_itineraries_qa.csv into the dataframe named ATL_itineraries_qa
# Successfully read ATL_itineraries_qb.csv into the dataframe named ATL_itineraries_qb
# Successfully read ATL_itineraries_qc.csv into the dataframe named ATL_itineraries_qc
# Successfully read ATL_itineraries_qd.csv into the dataframe named ATL_itineraries_qd
# Successfully read ATL_itineraries_qe.csv into the dataframe named ATL_itineraries_qe
# Successfully read ATL_itineraries_qf.csv into the dataframe named ATL_itineraries_qf
# Successfully read ATL_itineraries_qg.csv into the dataframe named ATL_itineraries_qg
# Successfully read ATL_itineraries_qh.csv into the dataframe named ATL_itineraries_qh
# Successfully read ATL_itineraries_qi.csv into the dataframe named ATL_itineraries_qi
# Successfully read ATL_itineraries_qj.csv into the dataframe named ATL_itineraries_qj
# Successfully read ATL_itineraries_qk.csv into the dataframe named ATL_itineraries_qk
# Successfully read ATL_itineraries_ql.csv into the dataframe named ATL_itineraries_ql
# Successfully read ATL_itineraries_qm.csv into the dataframe named ATL_itineraries_qm
# Successfully read ATL_itineraries_qn.csv into the dataframe named ATL_itineraries_qn
# Successfully read ATL_itineraries_qo.csv into the dataframe named ATL_itineraries_qo
# Successfully read ATL_itineraries_qp.csv into the dataframe named ATL_itineraries_qp
# Successfully read ATL_itineraries_qq.csv into the dataframe named ATL_itineraries_qq
# Successfully read ATL_itineraries_qr.csv into the dataframe named ATL_itineraries_qr
# Successfully read ATL_itineraries_qs.csv into the dataframe named ATL_itineraries_qs
# Successfully read ATL_itineraries_qt.csv into the dataframe named ATL_itineraries_qt
# Successfully read ATL_itineraries_qu.csv into the dataframe named ATL_itineraries_qu
# Successfully read ATL_itineraries_qv.csv into the dataframe named ATL_itineraries_qv
# Successfully read ATL_itineraries_qw.csv into the dataframe named ATL_itineraries_qw
# Successfully read ATL_itineraries_qx.csv into the dataframe named ATL_itineraries_qx
# Successfully read ATL_itineraries_qy.csv into the dataframe named ATL_itineraries_qy
# Successfully read ATL_itineraries_qz.csv into the dataframe named ATL_itineraries_qz
# Successfully read ATL_itineraries_ra.csv into the dataframe named ATL_itineraries_ra
# Successfully read ATL_itineraries_rb.csv into the dataframe named ATL_itineraries_rb
# Successfully read ATL_itineraries_rc.csv into the dataframe named ATL_itineraries_rc
# Successfully read ATL_itineraries_rd.csv into the dataframe named ATL_itineraries_rd
# Successfully read ATL_itineraries_re.csv into the dataframe named ATL_itineraries_re
# Successfully read ATL_itineraries_rf.csv into the dataframe named ATL_itineraries_rf
# Successfully read ATL_itineraries_rg.csv into the dataframe named ATL_itineraries_rg
# Successfully read ATL_itineraries_rh.csv into the dataframe named ATL_itineraries_rh
# Successfully read ATL_itineraries_ri.csv into the dataframe named ATL_itineraries_ri
# Successfully read ATL_itineraries_rj.csv into the dataframe named ATL_itineraries_rj
# Successfully read ATL_itineraries_rk.csv into the dataframe named ATL_itineraries_rk
# Successfully read ATL_itineraries_rl.csv into the dataframe named ATL_itineraries_rl
# Successfully read ATL_itineraries_rm.csv into the dataframe named ATL_itineraries_rm
# Successfully read ATL_itineraries_rn.csv into the dataframe named ATL_itineraries_rn
# Successfully read ATL_itineraries_ro.csv into the dataframe named ATL_itineraries_ro
# Successfully read ATL_itineraries_rp.csv into the dataframe named ATL_itineraries_rp
# Successfully read ATL_itineraries_rq.csv into the dataframe named ATL_itineraries_rq
# Successfully read ATL_itineraries_rr.csv into the dataframe named ATL_itineraries_rr
# Successfully read ATL_itineraries_rs.csv into the dataframe named ATL_itineraries_rs
# Successfully read ATL_itineraries_rt.csv into the dataframe named ATL_itineraries_rt
# Successfully read ATL_itineraries_ru.csv into the dataframe named ATL_itineraries_ru
# Successfully read ATL_itineraries_rv.csv into the dataframe named ATL_itineraries_rv
# Successfully read ATL_itineraries_rw.csv into the dataframe named ATL_itineraries_rw
# Successfully read ATL_itineraries_rx.csv into the dataframe named ATL_itineraries_rx
# Successfully read ATL_itineraries_ry.csv into the dataframe named ATL_itineraries_ry
# Successfully read ATL_itineraries_rz.csv into the dataframe named ATL_itineraries_rz
# Successfully read ATL_itineraries_sa.csv into the dataframe named ATL_itineraries_sa
# Successfully read ATL_itineraries_sb.csv into the dataframe named ATL_itineraries_sb
# Successfully read ATL_itineraries_sc.csv into the dataframe named ATL_itineraries_sc
# Successfully read ATL_itineraries_sd.csv into the dataframe named ATL_itineraries_sd
# Successfully read ATL_itineraries_se.csv into the dataframe named ATL_itineraries_se
# Successfully read ATL_itineraries_sf.csv into the dataframe named ATL_itineraries_sf
# Successfully read ATL_itineraries_sg.csv into the dataframe named ATL_itineraries_sg
# Successfully read ATL_itineraries_sh.csv into the dataframe named ATL_itineraries_sh
# Successfully read ATL_itineraries_si.csv into the dataframe named ATL_itineraries_si
# Successfully read ATL_itineraries_sj.csv into the dataframe named ATL_itineraries_sj
# Successfully read ATL_itineraries_sk.csv into the dataframe named ATL_itineraries_sk
# Successfully read ATL_itineraries_sl.csv into the dataframe named ATL_itineraries_sl
# Successfully read ATL_itineraries_sm.csv into the dataframe named ATL_itineraries_sm
# Successfully read ATL_itineraries_sn.csv into the dataframe named ATL_itineraries_sn
# Successfully read ATL_itineraries_so.csv into the dataframe named ATL_itineraries_so
# Successfully read ATL_itineraries_sp.csv into the dataframe named ATL_itineraries_sp
# Successfully read ATL_itineraries_sq.csv into the dataframe named ATL_itineraries_sq
# Successfully read ATL_itineraries_sr.csv into the dataframe named ATL_itineraries_sr
# Successfully read ATL_itineraries_ss.csv into the dataframe named ATL_itineraries_ss
# Successfully read ATL_itineraries_st.csv into the dataframe named ATL_itineraries_st
# Successfully read ATL_itineraries_su.csv into the dataframe named ATL_itineraries_su
# Successfully read ATL_itineraries_sv.csv into the dataframe named ATL_itineraries_sv
# Successfully read ATL_itineraries_sw.csv into the dataframe named ATL_itineraries_sw
# Successfully read ATL_itineraries_sx.csv into the dataframe named ATL_itineraries_sx
# Successfully read ATL_itineraries_sy.csv into the dataframe named ATL_itineraries_sy
# Successfully read ATL_itineraries_sz.csv into the dataframe named ATL_itineraries_sz
# Successfully read ATL_itineraries_ta.csv into the dataframe named ATL_itineraries_ta
# Successfully read ATL_itineraries_tb.csv into the dataframe named ATL_itineraries_tb
# Successfully read ATL_itineraries_tc.csv into the dataframe named ATL_itineraries_tc
# Successfully read ATL_itineraries_td.csv into the dataframe named ATL_itineraries_td
# Successfully read ATL_itineraries_te.csv into the dataframe named ATL_itineraries_te
# Successfully read ATL_itineraries_tf.csv into the dataframe named ATL_itineraries_tf
# Successfully read ATL_itineraries_tg.csv into the dataframe named ATL_itineraries_tg
# Successfully read ATL_itineraries_th.csv into the dataframe named ATL_itineraries_th
# Successfully read ATL_itineraries_ti.csv into the dataframe named ATL_itineraries_ti
# Successfully read ATL_itineraries_tj.csv into the dataframe named ATL_itineraries_tj
# Successfully read ATL_itineraries_tk.csv into the dataframe named ATL_itineraries_tk
# Successfully read ATL_itineraries_tl.csv into the dataframe named ATL_itineraries_tl
# Successfully read ATL_itineraries_tm.csv into the dataframe named ATL_itineraries_tm
# Successfully read ATL_itineraries_tn.csv into the dataframe named ATL_itineraries_tn
# Successfully read ATL_itineraries_to.csv into the dataframe named ATL_itineraries_to
# Successfully read ATL_itineraries_tp.csv into the dataframe named ATL_itineraries_tp
# Successfully read ATL_itineraries_tq.csv into the dataframe named ATL_itineraries_tq
# Successfully read ATL_itineraries_tr.csv into the dataframe named ATL_itineraries_tr
# Successfully read ATL_itineraries_ts.csv into the dataframe named ATL_itineraries_ts
# Successfully read ATL_itineraries_tt.csv into the dataframe named ATL_itineraries_tt
# Successfully read ATL_itineraries_tu.csv into the dataframe named ATL_itineraries_tu
# Successfully read ATL_itineraries_tv.csv into the dataframe named ATL_itineraries_tv
# Successfully read ATL_itineraries_tw.csv into the dataframe named ATL_itineraries_tw
# Successfully read ATL_itineraries_tx.csv into the dataframe named ATL_itineraries_tx
# Successfully read ATL_itineraries_ty.csv into the dataframe named ATL_itineraries_ty
# Successfully read ATL_itineraries_tz.csv into the dataframe named ATL_itineraries_tz
# Successfully read ATL_itineraries_ua.csv into the dataframe named ATL_itineraries_ua
# Successfully read ATL_itineraries_ub.csv into the dataframe named ATL_itineraries_ub
# Successfully read ATL_itineraries_uc.csv into the dataframe named ATL_itineraries_uc
# Successfully read ATL_itineraries_ud.csv into the dataframe named ATL_itineraries_ud
# Successfully read ATL_itineraries_ue.csv into the dataframe named ATL_itineraries_ue
# Successfully read ATL_itineraries_uf.csv into the dataframe named ATL_itineraries_uf
# Successfully read ATL_itineraries_ug.csv into the dataframe named ATL_itineraries_ug
# Successfully read ATL_itineraries_uh.csv into the dataframe named ATL_itineraries_uh
# Successfully read ATL_itineraries_ui.csv into the dataframe named ATL_itineraries_ui
# Successfully read ATL_itineraries_uj.csv into the dataframe named ATL_itineraries_uj
# Successfully read ATL_itineraries_uk.csv into the dataframe named ATL_itineraries_uk
# Successfully read ATL_itineraries_ul.csv into the dataframe named ATL_itineraries_ul
# Successfully read ATL_itineraries_um.csv into the dataframe named ATL_itineraries_um
# Successfully read ATL_itineraries_un.csv into the dataframe named ATL_itineraries_un
# Successfully read ATL_itineraries_uo.csv into the dataframe named ATL_itineraries_uo
# Successfully read ATL_itineraries_up.csv into the dataframe named ATL_itineraries_up
# Successfully read ATL_itineraries_uq.csv into the dataframe named ATL_itineraries_uq
# Successfully read ATL_itineraries_ur.csv into the dataframe named ATL_itineraries_ur
# Successfully read ATL_itineraries_us.csv into the dataframe named ATL_itineraries_us
# Successfully read ATL_itineraries_ut.csv into the dataframe named ATL_itineraries_ut
# Successfully read ATL_itineraries_uu.csv into the dataframe named ATL_itineraries_uu
# Successfully read ATL_itineraries_uv.csv into the dataframe named ATL_itineraries_uv
# Successfully read ATL_itineraries_uw.csv into the dataframe named ATL_itineraries_uw
# Successfully read ATL_itineraries_ux.csv into the dataframe named ATL_itineraries_ux
# Successfully read ATL_itineraries_uy.csv into the dataframe named ATL_itineraries_uy
# Successfully read ATL_itineraries_uz.csv into the dataframe named ATL_itineraries_uz
# Successfully read ATL_itineraries_va.csv into the dataframe named ATL_itineraries_va
# Successfully read ATL_itineraries_vb.csv into the dataframe named ATL_itineraries_vb
# Successfully read ATL_itineraries_vc.csv into the dataframe named ATL_itineraries_vc
# Successfully read ATL_itineraries_vd.csv into the dataframe named ATL_itineraries_vd
# Successfully read ATL_itineraries_ve.csv into the dataframe named ATL_itineraries_ve
# Successfully read ATL_itineraries_vf.csv into the dataframe named ATL_itineraries_vf
# Successfully read ATL_itineraries_vg.csv into the dataframe named ATL_itineraries_vg
# Successfully read ATL_itineraries_vh.csv into the dataframe named ATL_itineraries_vh
# Successfully read ATL_itineraries_vi.csv into the dataframe named ATL_itineraries_vi
# Successfully read ATL_itineraries_vj.csv into the dataframe named ATL_itineraries_vj
# Successfully read ATL_itineraries_vk.csv into the dataframe named ATL_itineraries_vk
# Successfully read ATL_itineraries_vl.csv into the dataframe named ATL_itineraries_vl
# Successfully read ATL_itineraries_vm.csv into the dataframe named ATL_itineraries_vm
# Successfully read ATL_itineraries_vn.csv into the dataframe named ATL_itineraries_vn
# Successfully read ATL_itineraries_vo.csv into the dataframe named ATL_itineraries_vo
# Successfully read ATL_itineraries_vp.csv into the dataframe named ATL_itineraries_vp
# Successfully read ATL_itineraries_vq.csv into the dataframe named ATL_itineraries_vq
# Successfully read ATL_itineraries_vr.csv into the dataframe named ATL_itineraries_vr
# ...
# Successfully read SFO_itineraries_su.csv into the dataframe named SFO_itineraries_su
# Successfully read SFO_itineraries_sv.csv into the dataframe named SFO_itineraries_sv
# Successfully read SFO_itineraries_sw.csv into the dataframe named SFO_itineraries_sw
# Successfully read SFO_itineraries_sx.csv into the dataframe named SFO_itineraries_sx
# Successfully read SFO_itineraries_sy.csv into the dataframe named SFO_itineraries_sy
# Successfully read SFO_itineraries_sz.csv into the dataframe named SFO_itineraries_sz
# Successfully read SFO_itineraries_ta.csv into the dataframe named SFO_itineraries_ta
# Successfully read SFO_itineraries_tb.csv into the dataframe named SFO_itineraries_tb
# Successfully read SFO_itineraries_tc.csv into the dataframe named SFO_itineraries_tc
# Successfully read SFO_itineraries_td.csv into the dataframe named SFO_itineraries_td
# Successfully read SFO_itineraries_te.csv into the dataframe named SFO_itineraries_te
# Successfully read SFO_itineraries_tf.csv into the dataframe named SFO_itineraries_tf
# Successfully read SFO_itineraries_tg.csv into the dataframe named SFO_itineraries_tg
# Successfully read SFO_itineraries_th.csv into the dataframe named SFO_itineraries_th
# Successfully read SFO_itineraries_ti.csv into the dataframe named SFO_itineraries_ti
# Successfully read SFO_itineraries_tj.csv into the dataframe named SFO_itineraries_tj
# Successfully read SFO_itineraries_tk.csv into the dataframe named SFO_itineraries_tk
# Successfully read SFO_itineraries_tl.csv into the dataframe named SFO_itineraries_tl
# Successfully read SFO_itineraries_tm.csv into the dataframe named SFO_itineraries_tm
# Successfully read SFO_itineraries_tn.csv into the dataframe named SFO_itineraries_tn
# Successfully read SFO_itineraries_to.csv into the dataframe named SFO_itineraries_to
# Successfully read SFO_itineraries_tp.csv into the dataframe named SFO_itineraries_tp
# Successfully read SFO_itineraries_tq.csv into the dataframe named SFO_itineraries_tq
# Successfully read SFO_itineraries_tr.csv into the dataframe named SFO_itineraries_tr
# Successfully read SFO_itineraries_ts.csv into the dataframe named SFO_itineraries_ts
# Successfully read SFO_itineraries_tt.csv into the dataframe named SFO_itineraries_tt
# Successfully read SFO_itineraries_tu.csv into the dataframe named SFO_itineraries_tu
# Successfully read SFO_itineraries_tv.csv into the dataframe named SFO_itineraries_tv
# Successfully read SFO_itineraries_tw.csv into the dataframe named SFO_itineraries_tw
# Successfully read SFO_itineraries_tx.csv into the dataframe named SFO_itineraries_tx
# Successfully read SFO_itineraries_ty.csv into the dataframe named SFO_itineraries_ty
# Successfully read SFO_itineraries_tz.csv into the dataframe named SFO_itineraries_tz
# Successfully read SFO_itineraries_ua.csv into the dataframe named SFO_itineraries_ua
# Successfully read SFO_itineraries_ub.csv into the dataframe named SFO_itineraries_ub
# Successfully read SFO_itineraries_uc.csv into the dataframe named SFO_itineraries_uc
# Successfully read SFO_itineraries_ud.csv into the dataframe named SFO_itineraries_ud
# Successfully read SFO_itineraries_ue.csv into the dataframe named SFO_itineraries_ue
# Successfully read SFO_itineraries_uf.csv into the dataframe named SFO_itineraries_uf
# Successfully read SFO_itineraries_ug.csv into the dataframe named SFO_itineraries_ug
# Successfully read SFO_itineraries_uh.csv into the dataframe named SFO_itineraries_uh
# Successfully read SFO_itineraries_ui.csv into the dataframe named SFO_itineraries_ui
# Successfully read SFO_itineraries_uj.csv into the dataframe named SFO_itineraries_uj
# Successfully read SFO_itineraries_uk.csv into the dataframe named SFO_itineraries_uk
# Successfully read SFO_itineraries_ul.csv into the dataframe named SFO_itineraries_ul
# Successfully read SFO_itineraries_um.csv into the dataframe named SFO_itineraries_um
# Successfully read SFO_itineraries_un.csv into the dataframe named SFO_itineraries_un
# Successfully read SFO_itineraries_uo.csv into the dataframe named SFO_itineraries_uo
# Successfully read SFO_itineraries_up.csv into the dataframe named SFO_itineraries_up
# Successfully read SFO_itineraries_uq.csv into the dataframe named SFO_itineraries_uq
# Successfully read SFO_itineraries_ur.csv into the dataframe named SFO_itineraries_ur
# Successfully read SFO_itineraries_us.csv into the dataframe named SFO_itineraries_us
# Successfully read SFO_itineraries_ut.csv into the dataframe named SFO_itineraries_ut
# Successfully read SFO_itineraries_uu.csv into the dataframe named SFO_itineraries_uu
# Successfully read SFO_itineraries_uv.csv into the dataframe named SFO_itineraries_uv
# Successfully read SFO_itineraries_uw.csv into the dataframe named SFO_itineraries_uw
# Successfully read SFO_itineraries_ux.csv into the dataframe named SFO_itineraries_ux
# Successfully read SFO_itineraries_uy.csv into the dataframe named SFO_itineraries_uy
# Successfully read SFO_itineraries_uz.csv into the dataframe named SFO_itineraries_uz
# Successfully read SFO_itineraries_va.csv into the dataframe named SFO_itineraries_va
# Successfully read SFO_itineraries_vb.csv into the dataframe named SFO_itineraries_vb
# Successfully read SFO_itineraries_vc.csv into the dataframe named SFO_itineraries_vc
# Successfully read SFO_itineraries_vd.csv into the dataframe named SFO_itineraries_vd
# Successfully read SFO_itineraries_ve.csv into the dataframe named SFO_itineraries_ve
# Successfully read SFO_itineraries_vf.csv into the dataframe named SFO_itineraries_vf
# Successfully read SFO_itineraries_vg.csv into the dataframe named SFO_itineraries_vg
# Successfully read SFO_itineraries_vh.csv into the dataframe named SFO_itineraries_vh
# Successfully read SFO_itineraries_vi.csv into the dataframe named SFO_itineraries_vi
# Successfully read SFO_itineraries_vj.csv into the dataframe named SFO_itineraries_vj
# Successfully read SFO_itineraries_vk.csv into the dataframe named SFO_itineraries_vk
# Successfully read SFO_itineraries_vl.csv into the dataframe named SFO_itineraries_vl
# Successfully read SFO_itineraries_vm.csv into the dataframe named SFO_itineraries_vm
# Successfully read SFO_itineraries_vn.csv into the dataframe named SFO_itineraries_vn
# Successfully read SFO_itineraries_vo.csv into the dataframe named SFO_itineraries_vo
# Successfully read SFO_itineraries_vp.csv into the dataframe named SFO_itineraries_vp
# Successfully read SFO_itineraries_vq.csv into the dataframe named SFO_itineraries_vq
# Successfully read SFO_itineraries_vr.csv into the dataframe named SFO_itineraries_vr
# Successfully read SFO_itineraries_vs.csv into the dataframe named SFO_itineraries_vs
# Successfully read SFO_itineraries_vt.csv into the dataframe named SFO_itineraries_vt
# Successfully read SFO_itineraries_vu.csv into the dataframe named SFO_itineraries_vu
# Successfully read SFO_itineraries_vv.csv into the dataframe named SFO_itineraries_vv
# Successfully read SFO_itineraries_vw.csv into the dataframe named SFO_itineraries_vw
# Successfully read SFO_itineraries_vx.csv into the dataframe named SFO_itineraries_vx
# Successfully read SFO_itineraries_vy.csv into the dataframe named SFO_itineraries_vy
# Successfully read SFO_itineraries_vz.csv into the dataframe named SFO_itineraries_vz
# Successfully read SFO_itineraries_wa.csv into the dataframe named SFO_itineraries_wa
# Successfully read SFO_itineraries_wb.csv into the dataframe named SFO_itineraries_wb
# Successfully read SFO_itineraries_wc.csv into the dataframe named SFO_itineraries_wc
# Successfully read SFO_itineraries_wd.csv into the dataframe named SFO_itineraries_wd
# Successfully read SFO_itineraries_we.csv into the dataframe named SFO_itineraries_we
# Successfully read SFO_itineraries_wf.csv into the dataframe named SFO_itineraries_wf
# Successfully read SFO_itineraries_wg.csv into the dataframe named SFO_itineraries_wg
# Successfully read SFO_itineraries_wh.csv into the dataframe named SFO_itineraries_wh
# Successfully read SFO_itineraries_wi.csv into the dataframe named SFO_itineraries_wi
# Successfully read SFO_itineraries_wj.csv into the dataframe named SFO_itineraries_wj
# Successfully read SFO_itineraries_wk.csv into the dataframe named SFO_itineraries_wk
# Successfully read SFO_itineraries_wl.csv into the dataframe named SFO_itineraries_wl
# Successfully read SFO_itineraries_wm.csv into the dataframe named SFO_itineraries_wm
# Successfully read SFO_itineraries_wn.csv into the dataframe named SFO_itineraries_wn
# Successfully read SFO_itineraries_wo.csv into the dataframe named SFO_itineraries_wo
# Successfully read SFO_itineraries_wp.csv into the dataframe named SFO_itineraries_wp
# Successfully read SFO_itineraries_wq.csv into the dataframe named SFO_itineraries_wq
# Successfully read SFO_itineraries_wr.csv into the dataframe named SFO_itineraries_wr
# Successfully read SFO_itineraries_ws.csv into the dataframe named SFO_itineraries_ws
# Successfully read SFO_itineraries_wt.csv into the dataframe named SFO_itineraries_wt
# Successfully read SFO_itineraries_wu.csv into the dataframe named SFO_itineraries_wu
# Successfully read SFO_itineraries_wv.csv into the dataframe named SFO_itineraries_wv
# Successfully read SFO_itineraries_ww.csv into the dataframe named SFO_itineraries_ww
# Successfully read SFO_itineraries_wx.csv into the dataframe named SFO_itineraries_wx
# Successfully read SFO_itineraries_wy.csv into the dataframe named SFO_itineraries_wy
# Successfully read SFO_itineraries_wz.csv into the dataframe named SFO_itineraries_wz
# Successfully read SFO_itineraries_xa.csv into the dataframe named SFO_itineraries_xa
# Successfully read SFO_itineraries_xb.csv into the dataframe named SFO_itineraries_xb
# Successfully read SFO_itineraries_xc.csv into the dataframe named SFO_itineraries_xc
# Successfully read SFO_itineraries_xd.csv into the dataframe named SFO_itineraries_xd
# Successfully read SFO_itineraries_xe.csv into the dataframe named SFO_itineraries_xe
# Successfully read SFO_itineraries_xf.csv into the dataframe named SFO_itineraries_xf
# Successfully read SFO_itineraries_xg.csv into the dataframe named SFO_itineraries_xg
# Successfully read SFO_itineraries_xh.csv into the dataframe named SFO_itineraries_xh
# Successfully read SFO_itineraries_xi.csv into the dataframe named SFO_itineraries_xi
# Successfully read SFO_itineraries_xj.csv into the dataframe named SFO_itineraries_xj
# Successfully read SFO_itineraries_xk.csv into the dataframe named SFO_itineraries_xk
# Successfully read SFO_itineraries_xl.csv into the dataframe named SFO_itineraries_xl
# Successfully read SFO_itineraries_xm.csv into the dataframe named SFO_itineraries_xm
# Successfully read SFO_itineraries_xn.csv into the dataframe named SFO_itineraries_xn
# Successfully read SFO_itineraries_xo.csv into the dataframe named SFO_itineraries_xo
# Successfully read SFO_itineraries_xp.csv into the dataframe named SFO_itineraries_xp
# Successfully read SFO_itineraries_xq.csv into the dataframe named SFO_itineraries_xq
# Successfully read SFO_itineraries_xr.csv into the dataframe named SFO_itineraries_xr
# Successfully read SFO_itineraries_xs.csv into the dataframe named SFO_itineraries_xs
# Successfully read SFO_itineraries_xt.csv into the dataframe named SFO_itineraries_xt
# Successfully read SFO_itineraries_xu.csv into the dataframe named SFO_itineraries_xu
# Successfully read SFO_itineraries_xv.csv into the dataframe named SFO_itineraries_xv
# Successfully read SFO_itineraries_xw.csv into the dataframe named SFO_itineraries_xw
# Successfully read SFO_itineraries_xx.csv into the dataframe named SFO_itineraries_xx
# Successfully read SFO_itineraries_xy.csv into the dataframe named SFO_itineraries_xy
# Successfully read SFO_itineraries_xz.csv into the dataframe named SFO_itineraries_xz
# Successfully read SFO_itineraries_ya.csv into the dataframe named SFO_itineraries_ya
# Successfully read SFO_itineraries_yb.csv into the dataframe named SFO_itineraries_yb
# Successfully read SFO_itineraries_yc.csv into the dataframe named SFO_itineraries_yc
# Successfully read SFO_itineraries_yd.csv into the dataframe named SFO_itineraries_yd
# Successfully read SFO_itineraries_ye.csv into the dataframe named SFO_itineraries_ye
# Successfully read SFO_itineraries_yf.csv into the dataframe named SFO_itineraries_yf
# Successfully read SFO_itineraries_yg.csv into the dataframe named SFO_itineraries_yg
# Successfully read SFO_itineraries_yh.csv into the dataframe named SFO_itineraries_yh
# Successfully read SFO_itineraries_yi.csv into the dataframe named SFO_itineraries_yi
# Successfully read SFO_itineraries_yj.csv into the dataframe named SFO_itineraries_yj
# Successfully read SFO_itineraries_yk.csv into the dataframe named SFO_itineraries_yk
# Successfully read SFO_itineraries_yl.csv into the dataframe named SFO_itineraries_yl
# Successfully read SFO_itineraries_ym.csv into the dataframe named SFO_itineraries_ym
# Successfully read SFO_itineraries_yn.csv into the dataframe named SFO_itineraries_yn
# Successfully read SFO_itineraries_yo.csv into the dataframe named SFO_itineraries_yo
# Successfully read SFO_itineraries_yp.csv into the dataframe named SFO_itineraries_yp
# Successfully read SFO_itineraries_yq.csv into the dataframe named SFO_itineraries_yq
# Successfully read SFO_itineraries_yr.csv into the dataframe named SFO_itineraries_yr
# Successfully read SFO_itineraries_ys.csv into the dataframe named SFO_itineraries_ys
# Successfully read SFO_itineraries_yt.csv into the dataframe named SFO_itineraries_yt
# Successfully read SFO_itineraries_yu.csv into the dataframe named SFO_itineraries_yu
# Successfully read SFO_itineraries_yv.csv into the dataframe named SFO_itineraries_yv
# Successfully read SFO_itineraries_yw.csv into the dataframe named SFO_itineraries_yw
# Successfully read SFO_itineraries_yx.csv into the dataframe named SFO_itineraries_yx
# Successfully read SFO_itineraries_yy.csv into the dataframe named SFO_itineraries_yy
# Successfully read SFO_itineraries_yz.csv into the dataframe named SFO_itineraries_yz
# Successfully read SFO_itineraries_za.csv into the dataframe named SFO_itineraries_za
# Successfully read SFO_itineraries_zb.csv into the dataframe named SFO_itineraries_zb
# Successfully read SFO_itineraries_zc.csv into the dataframe named SFO_itineraries_zc
# Successfully read SFO_itineraries_zd.csv into the dataframe named SFO_itineraries_zd
# Successfully read SFO_itineraries_ze.csv into the dataframe named SFO_itineraries_ze
# Successfully read SFO_itineraries_zf.csv into the dataframe named SFO_itineraries_zf
# Successfully read SFO_itineraries_zg.csv into the dataframe named SFO_itineraries_zg
# Successfully read SFO_itineraries_zh.csv into the dataframe named SFO_itineraries_zh
# Successfully read SFO_itineraries_zi.csv into the dataframe named SFO_itineraries_zi
# Successfully read SFO_itineraries_zj.csv into the dataframe named SFO_itineraries_zj
# Successfully read SFO_itineraries_zk.csv into the dataframe named SFO_itineraries_zk
# Successfully read SFO_itineraries_zl.csv into the dataframe named SFO_itineraries_zl
# Successfully read SFO_itineraries_zm.csv into the dataframe named SFO_itineraries_zm
# Successfully read SFO_itineraries_zn.csv into the dataframe named SFO_itineraries_zn
# Successfully read SFO_itineraries_zo.csv into the dataframe named SFO_itineraries_zo
# Successfully read SFO_itineraries_zp.csv into the dataframe named SFO_itineraries_zp
# Successfully read SFO_itineraries_zq.csv into the dataframe named SFO_itineraries_zq
# Successfully read SFO_itineraries_zr.csv into the dataframe named SFO_itineraries_zr
# Successfully read SFO_itineraries_zs.csv into the dataframe named SFO_itineraries_zs
# Successfully read SFO_itineraries_zt.csv into the dataframe named SFO_itineraries_zt
# Successfully read SFO_itineraries_zu.csv into the dataframe named SFO_itineraries_zu
# Successfully read SFO_itineraries_zv.csv into the dataframe named SFO_itineraries_zv
# Successfully read SFO_itineraries_zw.csv into the dataframe named SFO_itineraries_zw
# Successfully read SFO_itineraries_zx.csv into the dataframe named SFO_itineraries_zx
# Successfully read SFO_itineraries_zy.csv into the dataframe named SFO_itineraries_zy
# Successfully read SFO_itineraries_zz.csv into the dataframe named SFO_itineraries_zz

# %%
def merge_dataframes(dataframes):
  """
  Merges data from multiple dataframes into a single dataframe.
  :param dataframes: 
  :return: Multiple Dataframes merged into their respective parent folder name 
  """
  merged_dataframe = {}
  prefixes = set()
  for df_name in dataframes.keys():
    prefix = df_name[:3]
    if prefix not in prefixes:
      df_names = sorted([name for name in dataframes.keys() if name.startswith(prefix)])
      
      airport_df = pd.concat([dataframes[name] for name in df_names], ignore_index=True)
      merged_dataframe[prefix] = airport_df
      print(f"Successfully merged {df_name} with {prefix} ")
      prefixes.add(prefix)
      print(f"Prefixes: {prefixes} ")
  return merged_dataframe
  
  
merged_dataframes = merge_dataframes(dataframes)
# Out:
# Successfully merged ATL_itineraries_aa with ATL
# Prefixes: {'ATL'}
# Successfully merged BOS_itineraries_aa with BOS
# Prefixes: {'BOS', 'ATL'}
# Successfully merged CLT_itineraries_aa with CLT
# Prefixes: {'BOS', 'CLT', 'ATL'}
# Successfully merged DEN_itineraries_aa with DEN
# Prefixes: {'DEN', 'BOS', 'CLT', 'ATL'}
# Successfully merged DFW_itineraries_aa with DFW
# Prefixes: {'ATL', 'BOS', 'DEN', 'DFW', 'CLT'}
# Successfully merged DTW_itineraries_aa with DTW
# Prefixes: {'ATL', 'DTW', 'BOS', 'DEN', 'DFW', 'CLT'}
# Successfully merged EWR_itineraries_aa with EWR
# Prefixes: {'ATL', 'DTW', 'EWR', 'BOS', 'DEN', 'DFW', 'CLT'}
# Successfully merged IAD_itineraries_aa with IAD
# Prefixes: {'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'DFW', 'CLT'}
# Successfully merged JFK_itineraries_aa with JFK
# Prefixes: {'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'DFW', 'JFK', 'CLT'}
# Successfully merged LAX_itineraries_aa with LAX
# Prefixes: {'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'DFW', 'JFK', 'CLT', 'LAX'}
# Successfully merged LGA_itineraries_aa with LGA
# Prefixes: {'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}
# Successfully merged MIA_itineraries_aa with MIA
# Prefixes: {'MIA', 'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}
# Successfully merged OAK_itineraries_aa with OAK
# Prefixes: {'MIA', 'ATL', 'DTW', 'EWR', 'BOS', 'IAD', 'DEN', 'OAK', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}
# Successfully merged ORD_itineraries_aa with ORD
# Prefixes: {'MIA', 'ATL', 'DTW', 'EWR', 'BOS', 'ORD', 'IAD', 'DEN', 'OAK', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}
# Successfully merged PHL_itineraries_aa with PHL
# Prefixes: {'MIA', 'ATL', 'DTW', 'EWR', 'PHL', 'BOS', 'ORD', 'IAD', 'DEN', 'OAK', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}
# Successfully merged SFO_itineraries_aa with SFO
# Prefixes: {'MIA', 'ATL', 'DTW', 'EWR', 'PHL', 'BOS', 'ORD', 'IAD', 'DEN', 'OAK', 'SFO', 'DFW', 'LGA', 'JFK', 'CLT', 'LAX'}

# %%
merged_dataframes.keys()
# Out:
# dict_keys(['ATL', 'BOS', 'CLT', 'DEN', 'DFW', 'DTW', 'EWR', 'IAD', 'JFK', 'LAX', 'LGA', 'MIA', 'OAK', 'ORD', 'PHL', 'SFO'])

# %%
output_folder = "../data/processed"  

for airport_code, df in merged_dataframes.items():
  output_filepath = os.path.join(output_folder, f"{airport_code}.csv")
  df.to_csv(output_filepath, index=False)
  print(f"Saved {airport_code}.csv to {output_folder}")
# Out:
# Saved ATL.csv to ../data/processed
# Saved BOS.csv to ../data/processed
# Saved CLT.csv to ../data/processed
# Saved DEN.csv to ../data/processed
# Saved DFW.csv to ../data/processed
# Saved DTW.csv to ../data/processed
# Saved EWR.csv to ../data/processed
# Saved IAD.csv to ../data/processed
# Saved JFK.csv to ../data/processed
# Saved LAX.csv to ../data/processed
# Saved LGA.csv to ../data/processed
# Saved MIA.csv to ../data/processed
# Saved OAK.csv to ../data/processed
# Saved ORD.csv to ../data/processed
# Saved PHL.csv to ../data/processed
# Saved SFO.csv to ../data/processed

# %%
import os
import pandas as pd

output_folder = "../data/processed/"  

def read_data(output_folder):
  """
  Reads all CSV files from the output folder into a dictionary of DataFrames.

  Args:
    output_folder: Path to the folder containing CSV files.

  Returns:
    A dictionary of DataFrames where keys are airport codes and values are DataFrames.
  """
  dataframes = {}
  for filename in os.listdir(output_folder):
    if filename.endswith(".csv"):
      filepath = os.path.join(output_folder, filename)
      print(f"Reading {filepath}")
      airport_code = filename[:-4]
      try:
        df = pd.read_csv(filepath)
        dataframes[airport_code] = df
        print(f"Successfully read {filename} into DataFrame named '{airport_code}'")
      except Exception as e:
        print(f"ERROR: Could not read {filepath}: {e}")
        
  return dataframes

merged_dataframes = read_data(output_folder)

# Create separate variables for each DataFrame
for airport_code, df in merged_dataframes.items():
    globals()[f"{airport_code}_df"] = df
    print(f"Created DataFrame: {airport_code}_df")
# Out:
# Reading ../data/processed/all_airports.csv
# Successfully read all_airports.csv into DataFrame named 'all_airports'
# Reading ../data/processed/ATL.csv
# Successfully read ATL.csv into DataFrame named 'ATL'
# Reading ../data/processed/BOS.csv
# Successfully read BOS.csv into DataFrame named 'BOS'
# Reading ../data/processed/CLT.csv
# Successfully read CLT.csv into DataFrame named 'CLT'
# Reading ../data/processed/DEN.csv
# Successfully read DEN.csv into DataFrame named 'DEN'
# Reading ../data/processed/DFW.csv
# Successfully read DFW.csv into DataFrame named 'DFW'
# Reading ../data/processed/DTW.csv
# Successfully read DTW.csv into DataFrame named 'DTW'
# Reading ../data/processed/EWR.csv
# Successfully read EWR.csv into DataFrame named 'EWR'
# Reading ../data/processed/IAD.csv
# Successfully read IAD.csv into DataFrame named 'IAD'
# Reading ../data/processed/JFK.csv
# Successfully read JFK.csv into DataFrame named 'JFK'
# Reading ../data/processed/LAX.csv
# Successfully read LAX.csv into DataFrame named 'LAX'
# Reading ../data/processed/LGA.csv
# Successfully read LGA.csv into DataFrame named 'LGA'
# Reading ../data/processed/MIA.csv
# Successfully read MIA.csv into DataFrame named 'MIA'
# Reading ../data/processed/OAK.csv
# Successfully read OAK.csv into DataFrame named 'OAK'
# Reading ../data/processed/ORD.csv
# Successfully read ORD.csv into DataFrame named 'ORD'
# Reading ../data/processed/PHL.csv
# Successfully read PHL.csv into DataFrame named 'PHL'
# Reading ../data/processed/SFO.csv
# Successfully read SFO.csv into DataFrame named 'SFO'
# Created DataFrame: all_airports_df
# Created DataFrame: ATL_df
# Created DataFrame: BOS_df
# Created DataFrame: CLT_df
# Created DataFrame: DEN_df
# Created DataFrame: DFW_df
# Created DataFrame: DTW_df
# Created DataFrame: EWR_df
# Created DataFrame: IAD_df
# Created DataFrame: JFK_df
# Created DataFrame: LAX_df
# Created DataFrame: LGA_df
# Created DataFrame: MIA_df
# Created DataFrame: OAK_df
# Created DataFrame: ORD_df
# Created DataFrame: PHL_df
# Created DataFrame: SFO_df

# %%
ATL_df.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'travelDuration', 'isBasicEconomy',
#        'isRefundable', 'isNonStop', 'totalFare', 'totalTravelDistance',
#        'segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw',
#        'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw',
#        'segmentsArrivalAirportCode', 'segmentsDepartureAirportCode',
#        'segmentsAirlineName', 'segmentsAirlineCode',
#        'segmentsEquipmentDescription', 'segmentsDurationInSeconds',
#        'segmentsDistance', 'segmentsCabinCode'],
#       dtype='object')

# %%
ATL_df.shape
# Out:
# (874069, 23)

# %%
BOS_df.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'travelDuration', 'isBasicEconomy',
#        'isRefundable', 'isNonStop', 'totalFare', 'totalTravelDistance',
#        'segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw',
#        'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw',
#        'segmentsArrivalAirportCode', 'segmentsDepartureAirportCode',
#        'segmentsAirlineName', 'segmentsAirlineCode',
#        'segmentsEquipmentDescription', 'segmentsDurationInSeconds',
#        'segmentsDistance', 'segmentsCabinCode'],
#       dtype='object')

# %%
CLT_df.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'travelDuration', 'isBasicEconomy',
#        'isRefundable', 'isNonStop', 'totalFare', 'totalTravelDistance',
#        'segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw',
#        'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw',
#        'segmentsArrivalAirportCode', 'segmentsDepartureAirportCode',
#        'segmentsAirlineName', 'segmentsAirlineCode',
#        'segmentsEquipmentDescription', 'segmentsDurationInSeconds',
#        'segmentsDistance', 'segmentsCabinCode'],
#       dtype='object')

# %% [markdown]
# Data Exploration

# %%
ATL_df['isBasicEconomy'].nunique()
# Out:
# 2

# %%
ATL_df['segmentsAirlineName'].unique()
# Out:
# array(['Delta', 'JetBlue Airways', 'American Airlines||American Airlines',
#        'United||United', 'Spirit Airlines||Spirit Airlines',
#        'American Airlines', 'JetBlue Airways||JetBlue Airways',
#        'Frontier Airlines', 'United',
#        'Frontier Airlines||Frontier Airlines', 'Spirit Airlines',
#        'Delta||Delta', 'Delta||United',
#        'Delta||Cape Air||Cape Air||Delta', 'Delta||Delta||Delta',
#        'Delta||Cape Air||Cape Air||United', 'United||Delta',
#        'United||United||Delta',
#        'Frontier Airlines||Frontier Airlines||Frontier Airlines',
#        'Alaska Airlines',
#        'Spirit Airlines||Spirit Airlines||Spirit Airlines',
#        'Delta||United||Delta', 'United||United||Alaska Airlines',
#        'Alaska Airlines||Alaska Airlines',
#        'American Airlines||American Airlines||American Airlines',
#        'Delta||Alaska Airlines', 'United||Delta||Delta',
#        'United||Alaska Airlines', 'United||United||United',
#        'United||United||United||Delta',
#        'United||United||Alaska Airlines||Alaska Airlines',
#        'United||Alaska Airlines||Alaska Airlines',
#        'Alaska Airlines||Alaska Airlines||Alaska Airlines',
#        'Delta||Alaska Airlines||United',
#        'JetBlue Airways||JetBlue Airways||JetBlue Airways',
#        'JetBlue Airways||Cape Air||Cape Air', 'Delta||United||United',
#        'Delta||Alaska Airlines||Alaska Airlines',
#        'Alaska Airlines||United', 'Boutique Air||Boutique Air||United',
#        'Alaska Airlines||Alaska Airlines||United',
#        'American Airlines||Key Lime Air||Key Lime Air',
#        'American Airlines||American Airlines||Cape Air||Cape Air',
#        'United||Key Lime Air||Key Lime Air',
#        'Delta||Alaska Airlines||Delta',
#        'Delta||United||United||Alaska Airlines',
#        'United||Cape Air||Cape Air||Delta', 'Delta||Delta||United',
#        'Southern Airways Express||Southern Airways Express||American Airlines',
#        'Delta||Delta||Alaska Airlines', 'United||United||United||United'],
#       dtype=object)

# %%
all_airports_df = pd.concat(merged_dataframes.values(), ignore_index=True)

  # Save the combined DataFrame to a CSV file
combined_output_filepath = "../data/processed/all_airports.csv"  # Choose your output filepath
all_airports_df.to_csv(combined_output_filepath, index=False)
print(f"Saved combined DataFrame to {combined_output_filepath}")
# Out:
# Saved combined DataFrame to ../data/processed/all_airports.csv

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
combined_output_filepath = "../data/processed/all_airports.csv" 
# airport_df = pd.read_csv(combined_output_filepath)

# %%
def split_segments(row_data):
  segmented_columns = ['segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw', 'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw', 'segmentsArrivalAirportCode',
 'segmentsDepartureAirportCode', 'segmentsAirlineName', 'segmentsAirlineCode', 'segmentsEquipmentDescription', 'segmentsDurationInSeconds', 'segmentsDistance', 'segmentsCabinCode']
  if not row_data['isNonStop']:
    for column in segmented_columns:
        # Now split the column by '||' into 2 columns
      split_column = row_data[column].split('||')
      row_data[f"{column}_1"] , row_data[f"{column}_2"] = split_column[0], split_column[1]
      row_data.drop(columns=column, inplace=True)
  return row_data

# %%
batch_size = 10000
processed_batches = []
for chunk in pd.read_csv(combined_output_filepath, chunksize=batch_size):
    # Apply the split_segments function to each chunk
    processed_chunk = chunk.apply(split_segments, axis=1)
    # Append the processed chunk to the list
    processed_batches.append(processed_chunk)

# Concatenate the processed batches into a single DataFrame
df = pd.concat(processed_batches, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'segmentsDepartureTimeRaw_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\series.py:1298, in Series.__setitem__(self, key, value)
#    1297 try:
# -> 1298     self._set_with_engine(key, value, warn=warn)
#    1299 except KeyError:
#    1300     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1301     #  key that is not present in self.index.
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\series.py:1370, in Series._set_with_engine(self, key, value, warn)
#    1369 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1370     loc = self.index.get_loc(key)
#    1372     # this is equivalent to self._values[key] = value
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'segmentsDepartureTimeRaw_1'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 processed_batches = []
#       3 for chunk in pd.read_csv(combined_output_filepath, chunksize=batch_size):
#       4     # Apply the split_segments function to each chunk
# ----> 5     processed_chunk = chunk.apply(split_segments, axis=1)
#       6     # Append the processed chunk to the list
#       7     processed_batches.append(processed_chunk)
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[7], line 8, in split_segments(row_data)
#       5   for column in segmented_columns:
#       6       # Now split the column by '||' into 2 columns
#       7     split_column = row_data[column].split('||')
# ----> 8     row_data[f"{column}_1"] , row_data[f"{column}_2"] = split_column[0], split_column[1]
#       9     row_data.drop(columns=column, inplace=True)
#      10 return row_data
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\series.py:1322, in Series.__setitem__(self, key, value)
#    1319             self._set_values(key, value)
#    1320     else:
#    1321         # GH#12862 adding a new key to the Series
# -> 1322         self.loc[key] = value
#    1324 except (TypeError, ValueError, LossySetitemError):
#    1325     # The key was OK, but we cannot set the value losslessly
#    1326     indexer = self.index.get_loc(key)
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1929     indexer, missing = convert_missing_indexer(indexer)
#    1931     if missing:
# -> 1932         self._setitem_with_indexer_missing(indexer, value)
#    1933         return
#    1935 if name == "loc":
#    1936     # must come after setting of missing
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexing.py:2238, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2231 with warnings.catch_warnings():
#    2232     # TODO: re-issue this with setitem-specific message?
#    2233     warnings.filterwarnings(
#    2234         "ignore",
#    2235         "The behavior of Index.insert with object-dtype is deprecated",
#    2236         category=FutureWarning,
#    2237     )
# -> 2238     new_index = index.insert(len(index), indexer)
#    2240 # we have a coerced indexer, e.g. a float
#    2241 # that matches in an int64 Index, so
#    2242 # we will not create a duplicate index, rather
#    2243 # index to that element
#    2244 # e.g. 0.0 -> 0
#    2245 # GH#12246
#    2246 if index.is_unique:
#    2247     # pass new_index[-1:] instead if [new_index[-1]]
#    2248     #  so that we retain dtype
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexes\base.py:7012, in Index.insert(self, loc, item)
#    7009     loc = loc if loc >= 0 else loc - 1
#    7010     new_values[loc] = item
# -> 7012 out = Index._with_infer(new_values, name=self.name)
#    7013 if (
#    7014     using_pyarrow_string_dtype()
#    7015     and is_string_dtype(out.dtype)
#    7016     and new_values.dtype == object
#    7017 ):
#    7018     out = out.astype(new_values.dtype)
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\pandas\core\indexes\base.py:686, in Index._with_infer(cls, *args, **kwargs)
#     680 result = cls(*args, **kwargs)
#     682 if result.dtype == _dtype_obj and not result._is_multi:
#     683     # error: Argument 1 to "maybe_convert_objects" has incompatible type
#     684     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected
#     685     # "ndarray[Any, Any]"
# --> 686     values = lib.maybe_convert_objects(result._values)  # type: ignore[arg-type]
#     687     if values.dtype.kind in "iufb":
#     688         return Index(values, name=result.name)
#
# File lib.pyx:2543, in pandas._libs.lib.maybe_convert_objects()
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\numpy\_core\numeric.py:366, in full(shape, fill_value, dtype, order, device, like)
#     364     dtype = fill_value.dtype
#     365 a = empty(shape, dtype, order, device=device)
# --> 366 multiarray.copyto(a, fill_value, casting='unsafe')
#     367 return a
#
# File D:\Advanced Machine Learning UTS\Assignment 2\MLAA_AT3_Machine_Learning\.venv\Lib\site-packages\numpy\_core\multiarray.py:1101, in copyto(dst, src, casting, where)
#    1052     """
#    1053     unravel_index(indices, shape, order='C')
#    1054
#    (...)
#    1096
#    1097     """
#    1098     return (indices,)
# -> 1101 @array_function_from_c_func_and_dispatcher(_multiarray_umath.copyto)
#    1102 def copyto(dst, src, casting=None, where=None):
#    1103     """
#    1104     copyto(dst, src, casting='same_kind', where=True)
#    1105
#    (...)
#    1148
#    1149     """
#    1150     return (dst, src, where)
#
# KeyboardInterrupt:
